# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
input_layer = Input(shape=(len))

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          1152        input_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          16512       dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           8256        dense_4[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_4[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_5[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 254.3064 - y1_output_loss: 115.3116 - y2_output_loss: 136.6014 - y1_output_root_mean_squared_error: 10.7893 - y2_output_root_mean_squared_error: 11.7429 - val_loss: 31.5582 - val_y1_output_loss: 15.8097 - val_y2_output_loss: 14.7134 - val_y1_output_root_mean_squared_error: 4.0479 - val_y2_output_root_mean_squared_error: 3.8953
# Epoch 2/500
# 614/614 [==============================] - 0s 194us/sample - loss: 46.4524 - y1_output_loss: 14.6047 - y2_output_loss: 31.4663 - y1_output_root_mean_squared_error: 3.8390 - y2_output_root_mean_squared_error: 5.6315 - val_loss: 27.3322 - val_y1_output_loss: 12.5912 - val_y2_output_loss: 14.0183 - val_y1_output_root_mean_squared_error: 3.5983 - val_y2_output_root_mean_squared_error: 3.7927
# Epoch 3/500
# 614/614 [==============================] - 0s 180us/sample - loss: 26.4648 - y1_output_loss: 10.4911 - y2_output_loss: 15.8460 - y1_output_root_mean_squared_error: 3.2481 - y2_output_root_mean_squared_error: 3.9893 - val_loss: 20.6738 - val_y1_output_loss: 9.1387 - val_y2_output_loss: 11.4232 - val_y1_output_root_mean_squared_error: 3.0591 - val_y2_output_root_mean_squared_error: 3.3639
# Epoch 4/500
# 614/614 [==============================] - 0s 186us/sample - loss: 26.2666 - y1_output_loss: 9.8240 - y2_output_loss: 16.3269 - y1_output_root_mean_squared_error: 3.1355 - y2_output_root_mean_squared_error: 4.0541 - val_loss: 16.5570 - val_y1_output_loss: 7.9547 - val_y2_output_loss: 8.2203 - val_y1_output_root_mean_squared_error: 2.8550 - val_y2_output_root_mean_squared_error: 2.8993
# Epoch 5/500
# 614/614 [==============================] - 0s 181us/sample - loss: 28.5589 - y1_output_loss: 10.2626 - y2_output_loss: 18.0683 - y1_output_root_mean_squared_error: 3.2136 - y2_output_root_mean_squared_error: 4.2698 - val_loss: 16.1995 - val_y1_output_loss: 7.9921 - val_y2_output_loss: 7.9756 - val_y1_output_root_mean_squared_error: 2.8500 - val_y2_output_root_mean_squared_error: 2.8420
# Epoch 6/500
# 614/614 [==============================] - 0s 166us/sample - loss: 23.0644 - y1_output_loss: 9.0305 - y2_output_loss: 13.8965 - y1_output_root_mean_squared_error: 3.0070 - y2_output_root_mean_squared_error: 3.7446 - val_loss: 18.0453 - val_y1_output_loss: 9.0674 - val_y2_output_loss: 9.0490 - val_y1_output_root_mean_squared_error: 3.0266 - val_y2_output_root_mean_squared_error: 2.9808
# Epoch 7/500
# 614/614 [==============================] - 0s 173us/sample - loss: 21.4647 - y1_output_loss: 8.2234 - y2_output_loss: 13.2193 - y1_output_root_mean_squared_error: 2.8683 - y2_output_root_mean_squared_error: 3.6383 - val_loss: 17.5681 - val_y1_output_loss: 8.6543 - val_y2_output_loss: 9.1782 - val_y1_output_root_mean_squared_error: 2.9446 - val_y2_output_root_mean_squared_error: 2.9829
# Epoch 8/500
# 614/614 [==============================] - 0s 174us/sample - loss: 23.6603 - y1_output_loss: 8.5234 - y2_output_loss: 15.4426 - y1_output_root_mean_squared_error: 2.9180 - y2_output_root_mean_squared_error: 3.8917 - val_loss: 27.9643 - val_y1_output_loss: 10.8931 - val_y2_output_loss: 18.6439 - val_y1_output_root_mean_squared_error: 3.2589 - val_y2_output_root_mean_squared_error: 4.1646
# Epoch 9/500
# 614/614 [==============================] - 0s 182us/sample - loss: 21.4138 - y1_output_loss: 8.1852 - y2_output_loss: 13.0419 - y1_output_root_mean_squared_error: 2.8737 - y2_output_root_mean_squared_error: 3.6271 - val_loss: 28.1645 - val_y1_output_loss: 9.5639 - val_y2_output_loss: 18.0479 - val_y1_output_root_mean_squared_error: 3.1181 - val_y2_output_root_mean_squared_error: 4.2944
# Epoch 10/500
# 614/614 [==============================] - 0s 166us/sample - loss: 23.6982 - y1_output_loss: 8.3032 - y2_output_loss: 15.3494 - y1_output_root_mean_squared_error: 2.8797 - y2_output_root_mean_squared_error: 3.9250 - val_loss: 17.1893 - val_y1_output_loss: 8.9032 - val_y2_output_loss: 8.2888 - val_y1_output_root_mean_squared_error: 2.9875 - val_y2_output_root_mean_squared_error: 2.8747
# Epoch 11/500
# 614/614 [==============================] - 0s 182us/sample - loss: 18.8896 - y1_output_loss: 7.4825 - y2_output_loss: 11.4466 - y1_output_root_mean_squared_error: 2.7341 - y2_output_root_mean_squared_error: 3.3785 - val_loss: 22.6099 - val_y1_output_loss: 8.0897 - val_y2_output_loss: 14.1532 - val_y1_output_root_mean_squared_error: 2.8645 - val_y2_output_root_mean_squared_error: 3.7954
# Epoch 12/500
# 614/614 [==============================] - 0s 190us/sample - loss: 18.5134 - y1_output_loss: 6.9334 - y2_output_loss: 11.6014 - y1_output_root_mean_squared_error: 2.6155 - y2_output_root_mean_squared_error: 3.4166 - val_loss: 34.8663 - val_y1_output_loss: 12.9643 - val_y2_output_loss: 21.5345 - val_y1_output_root_mean_squared_error: 3.6159 - val_y2_output_root_mean_squared_error: 4.6681
# Epoch 13/500
# 614/614 [==============================] - 0s 175us/sample - loss: 17.1679 - y1_output_loss: 6.4676 - y2_output_loss: 10.5704 - y1_output_root_mean_squared_error: 2.5538 - y2_output_root_mean_squared_error: 3.2628 - val_loss: 12.3163 - val_y1_output_loss: 5.9778 - val_y2_output_loss: 6.5968 - val_y1_output_root_mean_squared_error: 2.4514 - val_y2_output_root_mean_squared_error: 2.5113
# Epoch 14/500
# 614/614 [==============================] - 0s 176us/sample - loss: 19.2353 - y1_output_loss: 6.8009 - y2_output_loss: 12.3104 - y1_output_root_mean_squared_error: 2.6189 - y2_output_root_mean_squared_error: 3.5180 - val_loss: 15.4925 - val_y1_output_loss: 5.7185 - val_y2_output_loss: 9.5289 - val_y1_output_root_mean_squared_error: 2.4121 - val_y2_output_root_mean_squared_error: 3.1104
# Epoch 15/500
# 614/614 [==============================] - 0s 149us/sample - loss: 16.6212 - y1_output_loss: 6.1910 - y2_output_loss: 10.3643 - y1_output_root_mean_squared_error: 2.4850 - y2_output_root_mean_squared_error: 3.2320 - val_loss: 16.7644 - val_y1_output_loss: 10.3417 - val_y2_output_loss: 6.9050 - val_y1_output_root_mean_squared_error: 3.1683 - val_y2_output_root_mean_squared_error: 2.5935
# Epoch 16/500
# 614/614 [==============================] - 0s 173us/sample - loss: 24.4654 - y1_output_loss: 8.0945 - y2_output_loss: 16.4266 - y1_output_root_mean_squared_error: 2.8523 - y2_output_root_mean_squared_error: 4.0410 - val_loss: 42.0610 - val_y1_output_loss: 8.8881 - val_y2_output_loss: 34.5240 - val_y1_output_root_mean_squared_error: 2.9700 - val_y2_output_root_mean_squared_error: 5.7654
# Epoch 17/500
# 614/614 [==============================] - 0s 165us/sample - loss: 16.8114 - y1_output_loss: 6.3186 - y2_output_loss: 10.3984 - y1_output_root_mean_squared_error: 2.5243 - y2_output_root_mean_squared_error: 3.2310 - val_loss: 14.6750 - val_y1_output_loss: 6.0972 - val_y2_output_loss: 8.9442 - val_y1_output_root_mean_squared_error: 2.4795 - val_y2_output_root_mean_squared_error: 2.9201
# Epoch 18/500
# 614/614 [==============================] - 0s 169us/sample - loss: 15.5354 - y1_output_loss: 5.5970 - y2_output_loss: 9.8077 - y1_output_root_mean_squared_error: 2.3756 - y2_output_root_mean_squared_error: 3.1452 - val_loss: 14.8158 - val_y1_output_loss: 5.5815 - val_y2_output_loss: 8.9509 - val_y1_output_root_mean_squared_error: 2.3887 - val_y2_output_root_mean_squared_error: 3.0183
# Epoch 19/500
# 614/614 [==============================] - 0s 176us/sample - loss: 15.0469 - y1_output_loss: 5.5750 - y2_output_loss: 9.3898 - y1_output_root_mean_squared_error: 2.3702 - y2_output_root_mean_squared_error: 3.0707 - val_loss: 10.2079 - val_y1_output_loss: 4.9774 - val_y2_output_loss: 5.4232 - val_y1_output_root_mean_squared_error: 2.2386 - val_y2_output_root_mean_squared_error: 2.2796
# Epoch 20/500
# 614/614 [==============================] - 0s 164us/sample - loss: 15.3930 - y1_output_loss: 5.3185 - y2_output_loss: 10.1759 - y1_output_root_mean_squared_error: 2.2984 - y2_output_root_mean_squared_error: 3.1797 - val_loss: 21.0677 - val_y1_output_loss: 6.6462 - val_y2_output_loss: 14.1454 - val_y1_output_root_mean_squared_error: 2.5970 - val_y2_output_root_mean_squared_error: 3.7846
# Epoch 21/500
# 614/614 [==============================] - 0s 187us/sample - loss: 13.2118 - y1_output_loss: 4.8626 - y2_output_loss: 8.2889 - y1_output_root_mean_squared_error: 2.2015 - y2_output_root_mean_squared_error: 2.8923 - val_loss: 11.2660 - val_y1_output_loss: 5.5548 - val_y2_output_loss: 5.6214 - val_y1_output_root_mean_squared_error: 2.3699 - val_y2_output_root_mean_squared_error: 2.3769
# Epoch 22/500
# 614/614 [==============================] - 0s 191us/sample - loss: 11.7046 - y1_output_loss: 4.5751 - y2_output_loss: 7.0399 - y1_output_root_mean_squared_error: 2.1492 - y2_output_root_mean_squared_error: 2.6619 - val_loss: 8.6433 - val_y1_output_loss: 3.9153 - val_y2_output_loss: 4.6842 - val_y1_output_root_mean_squared_error: 1.9976 - val_y2_output_root_mean_squared_error: 2.1571
# Epoch 23/500
# 614/614 [==============================] - 0s 183us/sample - loss: 13.9357 - y1_output_loss: 4.9320 - y2_output_loss: 8.9788 - y1_output_root_mean_squared_error: 2.2211 - y2_output_root_mean_squared_error: 3.0004 - val_loss: 14.0738 - val_y1_output_loss: 5.5197 - val_y2_output_loss: 8.2389 - val_y1_output_root_mean_squared_error: 2.3763 - val_y2_output_root_mean_squared_error: 2.9029
# Epoch 24/500
# 614/614 [==============================] - 0s 178us/sample - loss: 10.8996 - y1_output_loss: 4.2025 - y2_output_loss: 6.5986 - y1_output_root_mean_squared_error: 2.0589 - y2_output_root_mean_squared_error: 2.5808 - val_loss: 8.8730 - val_y1_output_loss: 3.6723 - val_y2_output_loss: 5.1293 - val_y1_output_root_mean_squared_error: 1.9341 - val_y2_output_root_mean_squared_error: 2.2654
# Epoch 25/500
# 614/614 [==============================] - 0s 166us/sample - loss: 10.8205 - y1_output_loss: 3.8527 - y2_output_loss: 6.9233 - y1_output_root_mean_squared_error: 1.9643 - y2_output_root_mean_squared_error: 2.6386 - val_loss: 8.2149 - val_y1_output_loss: 4.1463 - val_y2_output_loss: 3.9683 - val_y1_output_root_mean_squared_error: 2.0587 - val_y2_output_root_mean_squared_error: 1.9941
# Epoch 26/500
# 614/614 [==============================] - 0s 187us/sample - loss: 10.7499 - y1_output_loss: 3.7150 - y2_output_loss: 6.9464 - y1_output_root_mean_squared_error: 1.9338 - y2_output_root_mean_squared_error: 2.6477 - val_loss: 8.2843 - val_y1_output_loss: 3.6959 - val_y2_output_loss: 4.4289 - val_y1_output_root_mean_squared_error: 1.9514 - val_y2_output_root_mean_squared_error: 2.1157
# Epoch 27/500
# 614/614 [==============================] - 0s 196us/sample - loss: 11.4724 - y1_output_loss: 4.1300 - y2_output_loss: 7.3039 - y1_output_root_mean_squared_error: 2.0279 - y2_output_root_mean_squared_error: 2.7129 - val_loss: 10.4689 - val_y1_output_loss: 3.3109 - val_y2_output_loss: 7.0068 - val_y1_output_root_mean_squared_error: 1.8364 - val_y2_output_root_mean_squared_error: 2.6639
# Epoch 28/500
# 614/614 [==============================] - 0s 199us/sample - loss: 10.4111 - y1_output_loss: 3.8888 - y2_output_loss: 6.4448 - y1_output_root_mean_squared_error: 1.9773 - y2_output_root_mean_squared_error: 2.5498 - val_loss: 6.4885 - val_y1_output_loss: 2.9668 - val_y2_output_loss: 3.5337 - val_y1_output_root_mean_squared_error: 1.7424 - val_y2_output_root_mean_squared_error: 1.8581
# Epoch 29/500
# 614/614 [==============================] - 0s 209us/sample - loss: 8.9929 - y1_output_loss: 3.2592 - y2_output_loss: 5.6942 - y1_output_root_mean_squared_error: 1.8107 - y2_output_root_mean_squared_error: 2.3905 - val_loss: 12.7238 - val_y1_output_loss: 3.5833 - val_y2_output_loss: 8.9324 - val_y1_output_root_mean_squared_error: 1.9145 - val_y2_output_root_mean_squared_error: 3.0097
# Epoch 30/500
# 614/614 [==============================] - 0s 165us/sample - loss: 10.2183 - y1_output_loss: 3.3879 - y2_output_loss: 6.7407 - y1_output_root_mean_squared_error: 1.8487 - y2_output_root_mean_squared_error: 2.6078 - val_loss: 13.3691 - val_y1_output_loss: 4.2899 - val_y2_output_loss: 9.3762 - val_y1_output_root_mean_squared_error: 2.0854 - val_y2_output_root_mean_squared_error: 3.0033
# Epoch 31/500
# 614/614 [==============================] - 0s 190us/sample - loss: 10.7039 - y1_output_loss: 3.4568 - y2_output_loss: 7.1620 - y1_output_root_mean_squared_error: 1.8676 - y2_output_root_mean_squared_error: 2.6863 - val_loss: 8.6291 - val_y1_output_loss: 3.3823 - val_y2_output_loss: 5.2743 - val_y1_output_root_mean_squared_error: 1.8417 - val_y2_output_root_mean_squared_error: 2.2885
# Epoch 32/500
# 614/614 [==============================] - 0s 186us/sample - loss: 8.6591 - y1_output_loss: 2.8821 - y2_output_loss: 5.7365 - y1_output_root_mean_squared_error: 1.7003 - y2_output_root_mean_squared_error: 2.4016 - val_loss: 12.6628 - val_y1_output_loss: 4.3999 - val_y2_output_loss: 8.2152 - val_y1_output_root_mean_squared_error: 2.0983 - val_y2_output_root_mean_squared_error: 2.8740
# Epoch 33/500
# 614/614 [==============================] - 0s 179us/sample - loss: 8.7684 - y1_output_loss: 2.9225 - y2_output_loss: 5.8755 - y1_output_root_mean_squared_error: 1.7069 - y2_output_root_mean_squared_error: 2.4197 - val_loss: 8.4670 - val_y1_output_loss: 3.6951 - val_y2_output_loss: 4.9004 - val_y1_output_root_mean_squared_error: 1.9351 - val_y2_output_root_mean_squared_error: 2.1731
# Epoch 34/500
# 614/614 [==============================] - 0s 190us/sample - loss: 8.4447 - y1_output_loss: 2.7463 - y2_output_loss: 5.8796 - y1_output_root_mean_squared_error: 1.6545 - y2_output_root_mean_squared_error: 2.3890 - val_loss: 35.8452 - val_y1_output_loss: 6.7647 - val_y2_output_loss: 29.7545 - val_y1_output_root_mean_squared_error: 2.6094 - val_y2_output_root_mean_squared_error: 5.3885
# Epoch 35/500
# 614/614 [==============================] - 0s 174us/sample - loss: 10.5828 - y1_output_loss: 3.2373 - y2_output_loss: 7.3448 - y1_output_root_mean_squared_error: 1.8019 - y2_output_root_mean_squared_error: 2.7085 - val_loss: 10.3286 - val_y1_output_loss: 4.2645 - val_y2_output_loss: 5.8973 - val_y1_output_root_mean_squared_error: 2.0733 - val_y2_output_root_mean_squared_error: 2.4556
# Epoch 36/500
# 614/614 [==============================] - 0s 187us/sample - loss: 7.7949 - y1_output_loss: 2.6239 - y2_output_loss: 5.1254 - y1_output_root_mean_squared_error: 1.6250 - y2_output_root_mean_squared_error: 2.2703 - val_loss: 9.3623 - val_y1_output_loss: 3.4374 - val_y2_output_loss: 6.0207 - val_y1_output_root_mean_squared_error: 1.8734 - val_y2_output_root_mean_squared_error: 2.4192
# Epoch 37/500
# 614/614 [==============================] - 0s 187us/sample - loss: 9.8501 - y1_output_loss: 3.2006 - y2_output_loss: 6.6206 - y1_output_root_mean_squared_error: 1.7827 - y2_output_root_mean_squared_error: 2.5830 - val_loss: 8.9028 - val_y1_output_loss: 3.8890 - val_y2_output_loss: 4.8719 - val_y1_output_root_mean_squared_error: 1.9816 - val_y2_output_root_mean_squared_error: 2.2307
# Epoch 38/500
# 614/614 [==============================] - 0s 176us/sample - loss: 7.1854 - y1_output_loss: 2.3678 - y2_output_loss: 4.7898 - y1_output_root_mean_squared_error: 1.5461 - y2_output_root_mean_squared_error: 2.1897 - val_loss: 8.8917 - val_y1_output_loss: 2.9809 - val_y2_output_loss: 6.0028 - val_y1_output_root_mean_squared_error: 1.7479 - val_y2_output_root_mean_squared_error: 2.4159
# Epoch 39/500
# 614/614 [==============================] - 0s 191us/sample - loss: 7.7132 - y1_output_loss: 2.6329 - y2_output_loss: 5.3323 - y1_output_root_mean_squared_error: 1.6046 - y2_output_root_mean_squared_error: 2.2668 - val_loss: 31.6853 - val_y1_output_loss: 9.5870 - val_y2_output_loss: 22.1801 - val_y1_output_root_mean_squared_error: 3.0763 - val_y2_output_root_mean_squared_error: 4.7140
# Epoch 40/500
# 614/614 [==============================] - 0s 167us/sample - loss: 8.5582 - y1_output_loss: 2.8092 - y2_output_loss: 5.7166 - y1_output_root_mean_squared_error: 1.6752 - y2_output_root_mean_squared_error: 2.3983 - val_loss: 7.5184 - val_y1_output_loss: 3.1901 - val_y2_output_loss: 4.3923 - val_y1_output_root_mean_squared_error: 1.8005 - val_y2_output_root_mean_squared_error: 2.0680
# Epoch 41/500
# 614/614 [==============================] - 0s 179us/sample - loss: 7.1718 - y1_output_loss: 2.4587 - y2_output_loss: 4.6775 - y1_output_root_mean_squared_error: 1.5704 - y2_output_root_mean_squared_error: 2.1693 - val_loss: 8.5593 - val_y1_output_loss: 3.2831 - val_y2_output_loss: 5.3213 - val_y1_output_root_mean_squared_error: 1.8290 - val_y2_output_root_mean_squared_error: 2.2834
# Epoch 42/500
# 614/614 [==============================] - 0s 182us/sample - loss: 6.9531 - y1_output_loss: 2.4184 - y2_output_loss: 4.5659 - y1_output_root_mean_squared_error: 1.5503 - y2_output_root_mean_squared_error: 2.1330 - val_loss: 16.9782 - val_y1_output_loss: 5.9524 - val_y2_output_loss: 11.5439 - val_y1_output_root_mean_squared_error: 2.3843 - val_y2_output_root_mean_squared_error: 3.3606
# Epoch 43/500
# 614/614 [==============================] - 0s 175us/sample - loss: 7.4289 - y1_output_loss: 2.3535 - y2_output_loss: 5.0494 - y1_output_root_mean_squared_error: 1.5289 - y2_output_root_mean_squared_error: 2.2564 - val_loss: 9.3409 - val_y1_output_loss: 3.6166 - val_y2_output_loss: 5.6912 - val_y1_output_root_mean_squared_error: 1.8984 - val_y2_output_root_mean_squared_error: 2.3952
# Epoch 44/500
# 614/614 [==============================] - 0s 179us/sample - loss: 6.9743 - y1_output_loss: 2.2878 - y2_output_loss: 4.7181 - y1_output_root_mean_squared_error: 1.5013 - y2_output_root_mean_squared_error: 2.1727 - val_loss: 7.4012 - val_y1_output_loss: 3.2949 - val_y2_output_loss: 3.9390 - val_y1_output_root_mean_squared_error: 1.8309 - val_y2_output_root_mean_squared_error: 2.0122
# Epoch 45/500
# 614/614 [==============================] - 0s 157us/sample - loss: 5.8716 - y1_output_loss: 1.9361 - y2_output_loss: 3.8979 - y1_output_root_mean_squared_error: 1.3966 - y2_output_root_mean_squared_error: 1.9802 - val_loss: 7.6999 - val_y1_output_loss: 2.5443 - val_y2_output_loss: 5.2124 - val_y1_output_root_mean_squared_error: 1.6146 - val_y2_output_root_mean_squared_error: 2.2568
# Epoch 46/500
# 614/614 [==============================] - 0s 177us/sample - loss: 5.9179 - y1_output_loss: 1.9916 - y2_output_loss: 3.9795 - y1_output_root_mean_squared_error: 1.4095 - y2_output_root_mean_squared_error: 1.9828 - val_loss: 7.0853 - val_y1_output_loss: 3.5662 - val_y2_output_loss: 3.5132 - val_y1_output_root_mean_squared_error: 1.8964 - val_y2_output_root_mean_squared_error: 1.8679
# Epoch 47/500
# 614/614 [==============================] - 0s 181us/sample - loss: 5.7800 - y1_output_loss: 1.8040 - y2_output_loss: 3.9931 - y1_output_root_mean_squared_error: 1.3450 - y2_output_root_mean_squared_error: 1.9927 - val_loss: 6.7555 - val_y1_output_loss: 2.4435 - val_y2_output_loss: 4.2188 - val_y1_output_root_mean_squared_error: 1.5824 - val_y2_output_root_mean_squared_error: 2.0619
# Epoch 48/500
# 614/614 [==============================] - 0s 165us/sample - loss: 5.1989 - y1_output_loss: 1.6798 - y2_output_loss: 3.6220 - y1_output_root_mean_squared_error: 1.2997 - y2_output_root_mean_squared_error: 1.8734 - val_loss: 19.4644 - val_y1_output_loss: 2.5899 - val_y2_output_loss: 16.8398 - val_y1_output_root_mean_squared_error: 1.6060 - val_y2_output_root_mean_squared_error: 4.1092
# Epoch 49/500
# 614/614 [==============================] - 0s 175us/sample - loss: 6.3392 - y1_output_loss: 2.0028 - y2_output_loss: 4.2947 - y1_output_root_mean_squared_error: 1.4209 - y2_output_root_mean_squared_error: 2.0785 - val_loss: 5.4050 - val_y1_output_loss: 2.2020 - val_y2_output_loss: 3.0758 - val_y1_output_root_mean_squared_error: 1.5086 - val_y2_output_root_mean_squared_error: 1.7689
# Epoch 50/500
# 614/614 [==============================] - 0s 156us/sample - loss: 5.7764 - y1_output_loss: 1.9068 - y2_output_loss: 3.8589 - y1_output_root_mean_squared_error: 1.3795 - y2_output_root_mean_squared_error: 1.9681 - val_loss: 17.4675 - val_y1_output_loss: 5.1147 - val_y2_output_loss: 12.6533 - val_y1_output_root_mean_squared_error: 2.2705 - val_y2_output_root_mean_squared_error: 3.5089
# Epoch 51/500
# 614/614 [==============================] - 0s 174us/sample - loss: 5.9528 - y1_output_loss: 1.8967 - y2_output_loss: 4.0342 - y1_output_root_mean_squared_error: 1.3732 - y2_output_root_mean_squared_error: 2.0167 - val_loss: 5.9731 - val_y1_output_loss: 2.7187 - val_y2_output_loss: 3.2069 - val_y1_output_root_mean_squared_error: 1.6510 - val_y2_output_root_mean_squared_error: 1.8021
# Epoch 52/500
# 614/614 [==============================] - 0s 178us/sample - loss: 7.4430 - y1_output_loss: 2.0186 - y2_output_loss: 5.3646 - y1_output_root_mean_squared_error: 1.4267 - y2_output_root_mean_squared_error: 2.3254 - val_loss: 8.9809 - val_y1_output_loss: 3.3477 - val_y2_output_loss: 5.8114 - val_y1_output_root_mean_squared_error: 1.8099 - val_y2_output_root_mean_squared_error: 2.3885
# Epoch 53/500
# 614/614 [==============================] - 0s 165us/sample - loss: 6.8233 - y1_output_loss: 2.0422 - y2_output_loss: 5.0708 - y1_output_root_mean_squared_error: 1.4030 - y2_output_root_mean_squared_error: 2.2034 - val_loss: 27.8675 - val_y1_output_loss: 8.5052 - val_y2_output_loss: 19.7491 - val_y1_output_root_mean_squared_error: 2.9152 - val_y2_output_root_mean_squared_error: 4.4010
# Epoch 54/500
# 614/614 [==============================] - 0s 174us/sample - loss: 8.5847 - y1_output_loss: 2.6456 - y2_output_loss: 5.9005 - y1_output_root_mean_squared_error: 1.6329 - y2_output_root_mean_squared_error: 2.4328 - val_loss: 9.9373 - val_y1_output_loss: 2.6514 - val_y2_output_loss: 7.3935 - val_y1_output_root_mean_squared_error: 1.6474 - val_y2_output_root_mean_squared_error: 2.6876
# Epoch 55/500
# 614/614 [==============================] - 0s 180us/sample - loss: 5.2373 - y1_output_loss: 1.6339 - y2_output_loss: 3.5596 - y1_output_root_mean_squared_error: 1.2839 - y2_output_root_mean_squared_error: 1.8944 - val_loss: 8.8094 - val_y1_output_loss: 3.5790 - val_y2_output_loss: 5.4189 - val_y1_output_root_mean_squared_error: 1.8600 - val_y2_output_root_mean_squared_error: 2.3130
# Epoch 56/500
# 614/614 [==============================] - 0s 170us/sample - loss: 6.4858 - y1_output_loss: 1.8721 - y2_output_loss: 4.6240 - y1_output_root_mean_squared_error: 1.3691 - y2_output_root_mean_squared_error: 2.1474 - val_loss: 7.4570 - val_y1_output_loss: 2.5743 - val_y2_output_loss: 4.9647 - val_y1_output_root_mean_squared_error: 1.6139 - val_y2_output_root_mean_squared_error: 2.2028
# Epoch 57/500
# 614/614 [==============================] - 0s 183us/sample - loss: 6.6998 - y1_output_loss: 2.0531 - y2_output_loss: 4.6421 - y1_output_root_mean_squared_error: 1.4277 - y2_output_root_mean_squared_error: 2.1591 - val_loss: 7.3743 - val_y1_output_loss: 3.1774 - val_y2_output_loss: 4.0644 - val_y1_output_root_mean_squared_error: 1.8029 - val_y2_output_root_mean_squared_error: 2.0307
# Epoch 58/500
# 614/614 [==============================] - 0s 180us/sample - loss: 6.2124 - y1_output_loss: 1.9129 - y2_output_loss: 4.2416 - y1_output_root_mean_squared_error: 1.3893 - y2_output_root_mean_squared_error: 2.0694 - val_loss: 4.5019 - val_y1_output_loss: 1.7588 - val_y2_output_loss: 2.7115 - val_y1_output_root_mean_squared_error: 1.3315 - val_y2_output_root_mean_squared_error: 1.6520
# Epoch 59/500
# 614/614 [==============================] - 0s 174us/sample - loss: 5.7848 - y1_output_loss: 1.5674 - y2_output_loss: 4.1748 - y1_output_root_mean_squared_error: 1.2539 - y2_output_root_mean_squared_error: 2.0524 - val_loss: 7.9046 - val_y1_output_loss: 3.3788 - val_y2_output_loss: 4.5800 - val_y1_output_root_mean_squared_error: 1.8192 - val_y2_output_root_mean_squared_error: 2.1436
# Epoch 60/500
# 614/614 [==============================] - 0s 170us/sample - loss: 5.2917 - y1_output_loss: 1.6730 - y2_output_loss: 3.6267 - y1_output_root_mean_squared_error: 1.2955 - y2_output_root_mean_squared_error: 1.9009 - val_loss: 7.2121 - val_y1_output_loss: 1.7680 - val_y2_output_loss: 5.3294 - val_y1_output_root_mean_squared_error: 1.3420 - val_y2_output_root_mean_squared_error: 2.3262
# Epoch 61/500
# 614/614 [==============================] - 0s 166us/sample - loss: 4.5555 - y1_output_loss: 1.5500 - y2_output_loss: 3.0524 - y1_output_root_mean_squared_error: 1.2480 - y2_output_root_mean_squared_error: 1.7314 - val_loss: 4.6263 - val_y1_output_loss: 1.4024 - val_y2_output_loss: 3.2086 - val_y1_output_root_mean_squared_error: 1.1993 - val_y2_output_root_mean_squared_error: 1.7855
# Epoch 62/500
# 614/614 [==============================] - 0s 168us/sample - loss: 4.8247 - y1_output_loss: 1.3733 - y2_output_loss: 3.4851 - y1_output_root_mean_squared_error: 1.1759 - y2_output_root_mean_squared_error: 1.8553 - val_loss: 8.8998 - val_y1_output_loss: 2.8919 - val_y2_output_loss: 5.9575 - val_y1_output_root_mean_squared_error: 1.7252 - val_y2_output_root_mean_squared_error: 2.4338
# Epoch 63/500
# 614/614 [==============================] - 0s 176us/sample - loss: 3.8095 - y1_output_loss: 1.1295 - y2_output_loss: 2.6457 - y1_output_root_mean_squared_error: 1.0675 - y2_output_root_mean_squared_error: 1.6340 - val_loss: 3.4864 - val_y1_output_loss: 1.2036 - val_y2_output_loss: 2.2134 - val_y1_output_root_mean_squared_error: 1.1153 - val_y2_output_root_mean_squared_error: 1.4975
# Epoch 64/500
# 614/614 [==============================] - 0s 169us/sample - loss: 4.4061 - y1_output_loss: 1.2877 - y2_output_loss: 3.1527 - y1_output_root_mean_squared_error: 1.1351 - y2_output_root_mean_squared_error: 1.7657 - val_loss: 5.7555 - val_y1_output_loss: 2.3160 - val_y2_output_loss: 3.3500 - val_y1_output_root_mean_squared_error: 1.5269 - val_y2_output_root_mean_squared_error: 1.8504
# Epoch 65/500
# 614/614 [==============================] - 0s 169us/sample - loss: 5.7300 - y1_output_loss: 1.7675 - y2_output_loss: 4.2337 - y1_output_root_mean_squared_error: 1.2714 - y2_output_root_mean_squared_error: 2.0282 - val_loss: 52.1470 - val_y1_output_loss: 19.3890 - val_y2_output_loss: 33.3403 - val_y1_output_root_mean_squared_error: 4.3585 - val_y2_output_root_mean_squared_error: 5.7577
# Epoch 66/500
# 614/614 [==============================] - 0s 166us/sample - loss: 4.3899 - y1_output_loss: 1.3710 - y2_output_loss: 3.0613 - y1_output_root_mean_squared_error: 1.1759 - y2_output_root_mean_squared_error: 1.7341 - val_loss: 9.9206 - val_y1_output_loss: 2.1457 - val_y2_output_loss: 7.8310 - val_y1_output_root_mean_squared_error: 1.4378 - val_y2_output_root_mean_squared_error: 2.8024
# Epoch 67/500
# 614/614 [==============================] - 0s 168us/sample - loss: 4.5814 - y1_output_loss: 1.2768 - y2_output_loss: 3.2693 - y1_output_root_mean_squared_error: 1.1343 - y2_output_root_mean_squared_error: 1.8151 - val_loss: 4.0955 - val_y1_output_loss: 1.5287 - val_y2_output_loss: 2.4740 - val_y1_output_root_mean_squared_error: 1.2511 - val_y2_output_root_mean_squared_error: 1.5907
# Epoch 68/500
# 614/614 [==============================] - 0s 182us/sample - loss: 4.9796 - y1_output_loss: 1.2315 - y2_output_loss: 3.7348 - y1_output_root_mean_squared_error: 1.1101 - y2_output_root_mean_squared_error: 1.9358 - val_loss: 4.1010 - val_y1_output_loss: 1.4314 - val_y2_output_loss: 2.5496 - val_y1_output_root_mean_squared_error: 1.2085 - val_y2_output_root_mean_squared_error: 1.6250
# Epoch 69/500
# 614/614 [==============================] - 0s 171us/sample - loss: 3.3138 - y1_output_loss: 0.9000 - y2_output_loss: 2.4292 - y1_output_root_mean_squared_error: 0.9486 - y2_output_root_mean_squared_error: 1.5537 - val_loss: 3.2139 - val_y1_output_loss: 1.1226 - val_y2_output_loss: 1.9908 - val_y1_output_root_mean_squared_error: 1.0768 - val_y2_output_root_mean_squared_error: 1.4333
# Epoch 70/500
# 614/614 [==============================] - 0s 168us/sample - loss: 3.4671 - y1_output_loss: 0.9903 - y2_output_loss: 2.4531 - y1_output_root_mean_squared_error: 0.9988 - y2_output_root_mean_squared_error: 1.5715 - val_loss: 4.6394 - val_y1_output_loss: 1.7996 - val_y2_output_loss: 2.9067 - val_y1_output_root_mean_squared_error: 1.3196 - val_y2_output_root_mean_squared_error: 1.7024
# Epoch 71/500
# 614/614 [==============================] - 0s 174us/sample - loss: 4.6561 - y1_output_loss: 1.4035 - y2_output_loss: 3.2321 - y1_output_root_mean_squared_error: 1.1857 - y2_output_root_mean_squared_error: 1.8028 - val_loss: 4.2190 - val_y1_output_loss: 1.1838 - val_y2_output_loss: 2.9108 - val_y1_output_root_mean_squared_error: 1.1011 - val_y2_output_root_mean_squared_error: 1.7339
# Epoch 72/500
# 614/614 [==============================] - 0s 185us/sample - loss: 5.9384 - y1_output_loss: 1.8438 - y2_output_loss: 4.0633 - y1_output_root_mean_squared_error: 1.3605 - y2_output_root_mean_squared_error: 2.0217 - val_loss: 6.9719 - val_y1_output_loss: 2.1331 - val_y2_output_loss: 5.0182 - val_y1_output_root_mean_squared_error: 1.4221 - val_y2_output_root_mean_squared_error: 2.2248
# Epoch 73/500
# 614/614 [==============================] - 0s 181us/sample - loss: 3.6708 - y1_output_loss: 1.0218 - y2_output_loss: 2.6335 - y1_output_root_mean_squared_error: 1.0151 - y2_output_root_mean_squared_error: 1.6249 - val_loss: 5.7854 - val_y1_output_loss: 1.5317 - val_y2_output_loss: 4.2528 - val_y1_output_root_mean_squared_error: 1.2584 - val_y2_output_root_mean_squared_error: 2.0498
# Epoch 74/500
# 614/614 [==============================] - 0s 172us/sample - loss: 2.8976 - y1_output_loss: 0.8200 - y2_output_loss: 2.0607 - y1_output_root_mean_squared_error: 0.9085 - y2_output_root_mean_squared_error: 1.4395 - val_loss: 3.0767 - val_y1_output_loss: 0.8762 - val_y2_output_loss: 2.1748 - val_y1_output_root_mean_squared_error: 0.9463 - val_y2_output_root_mean_squared_error: 1.4769
# Epoch 75/500
# 614/614 [==============================] - 0s 181us/sample - loss: 2.7955 - y1_output_loss: 0.7857 - y2_output_loss: 2.1199 - y1_output_root_mean_squared_error: 0.8802 - y2_output_root_mean_squared_error: 1.4215 - val_loss: 30.0742 - val_y1_output_loss: 8.3243 - val_y2_output_loss: 22.1685 - val_y1_output_root_mean_squared_error: 2.8814 - val_y2_output_root_mean_squared_error: 4.6660
# Epoch 76/500
# 614/614 [==============================] - 0s 170us/sample - loss: 4.7198 - y1_output_loss: 1.3542 - y2_output_loss: 3.3488 - y1_output_root_mean_squared_error: 1.1671 - y2_output_root_mean_squared_error: 1.8324 - val_loss: 5.2697 - val_y1_output_loss: 2.1176 - val_y2_output_loss: 3.0977 - val_y1_output_root_mean_squared_error: 1.4656 - val_y2_output_root_mean_squared_error: 1.7669
# Epoch 77/500
# 614/614 [==============================] - 0s 179us/sample - loss: 4.2641 - y1_output_loss: 1.2254 - y2_output_loss: 3.0297 - y1_output_root_mean_squared_error: 1.1080 - y2_output_root_mean_squared_error: 1.7425 - val_loss: 4.3433 - val_y1_output_loss: 1.3889 - val_y2_output_loss: 2.9927 - val_y1_output_root_mean_squared_error: 1.1576 - val_y2_output_root_mean_squared_error: 1.7330
# Epoch 78/500
# 614/614 [==============================] - 0s 186us/sample - loss: 11.8424 - y1_output_loss: 3.7067 - y2_output_loss: 8.0521 - y1_output_root_mean_squared_error: 1.9278 - y2_output_root_mean_squared_error: 2.8506 - val_loss: 8.1606 - val_y1_output_loss: 4.0832 - val_y2_output_loss: 4.4675 - val_y1_output_root_mean_squared_error: 1.9539 - val_y2_output_root_mean_squared_error: 2.0840
# Epoch 79/500
# 614/614 [==============================] - 0s 201us/sample - loss: 4.3313 - y1_output_loss: 1.4214 - y2_output_loss: 2.9066 - y1_output_root_mean_squared_error: 1.1920 - y2_output_root_mean_squared_error: 1.7060 - val_loss: 3.1806 - val_y1_output_loss: 1.0710 - val_y2_output_loss: 2.0556 - val_y1_output_root_mean_squared_error: 1.0444 - val_y2_output_root_mean_squared_error: 1.4456
# Epoch 80/500
# 614/614 [==============================] - 0s 171us/sample - loss: 2.9952 - y1_output_loss: 0.8647 - y2_output_loss: 2.1088 - y1_output_root_mean_squared_error: 0.9311 - y2_output_root_mean_squared_error: 1.4588 - val_loss: 3.0535 - val_y1_output_loss: 1.0295 - val_y2_output_loss: 1.9490 - val_y1_output_root_mean_squared_error: 1.0249 - val_y2_output_root_mean_squared_error: 1.4153
# Epoch 81/500
# 614/614 [==============================] - 0s 163us/sample - loss: 3.4573 - y1_output_loss: 0.9247 - y2_output_loss: 2.5269 - y1_output_root_mean_squared_error: 0.9581 - y2_output_root_mean_squared_error: 1.5935 - val_loss: 3.9554 - val_y1_output_loss: 1.3296 - val_y2_output_loss: 2.5643 - val_y1_output_root_mean_squared_error: 1.1724 - val_y2_output_root_mean_squared_error: 1.6065
# Epoch 82/500
# 614/614 [==============================] - 0s 179us/sample - loss: 2.8982 - y1_output_loss: 0.7615 - y2_output_loss: 2.1851 - y1_output_root_mean_squared_error: 0.8753 - y2_output_root_mean_squared_error: 1.4602 - val_loss: 3.7754 - val_y1_output_loss: 0.8754 - val_y2_output_loss: 2.8090 - val_y1_output_root_mean_squared_error: 0.9438 - val_y2_output_root_mean_squared_error: 1.6984
# Epoch 83/500
# 614/614 [==============================] - 0s 169us/sample - loss: 3.9101 - y1_output_loss: 1.0397 - y2_output_loss: 2.8447 - y1_output_root_mean_squared_error: 1.0228 - y2_output_root_mean_squared_error: 1.6923 - val_loss: 3.1221 - val_y1_output_loss: 0.8733 - val_y2_output_loss: 2.2245 - val_y1_output_root_mean_squared_error: 0.9484 - val_y2_output_root_mean_squared_error: 1.4909
# Epoch 84/500
# 614/614 [==============================] - 0s 173us/sample - loss: 3.0812 - y1_output_loss: 0.8331 - y2_output_loss: 2.2545 - y1_output_root_mean_squared_error: 0.9127 - y2_output_root_mean_squared_error: 1.4994 - val_loss: 9.3575 - val_y1_output_loss: 2.9536 - val_y2_output_loss: 6.5807 - val_y1_output_root_mean_squared_error: 1.6795 - val_y2_output_root_mean_squared_error: 2.5567
# Epoch 85/500
# 614/614 [==============================] - 0s 190us/sample - loss: 4.2813 - y1_output_loss: 1.3649 - y2_output_loss: 2.9194 - y1_output_root_mean_squared_error: 1.1701 - y2_output_root_mean_squared_error: 1.7065 - val_loss: 3.3942 - val_y1_output_loss: 1.0228 - val_y2_output_loss: 2.4233 - val_y1_output_root_mean_squared_error: 0.9906 - val_y2_output_root_mean_squared_error: 1.5533
# Epoch 86/500
# 614/614 [==============================] - 0s 170us/sample - loss: 3.1673 - y1_output_loss: 0.8898 - y2_output_loss: 2.2652 - y1_output_root_mean_squared_error: 0.9437 - y2_output_root_mean_squared_error: 1.5089 - val_loss: 6.7422 - val_y1_output_loss: 2.3549 - val_y2_output_loss: 4.6280 - val_y1_output_root_mean_squared_error: 1.4806 - val_y2_output_root_mean_squared_error: 2.1331
# Epoch 87/500
# 614/614 [==============================] - 0s 202us/sample - loss: 3.1433 - y1_output_loss: 0.8447 - y2_output_loss: 2.2945 - y1_output_root_mean_squared_error: 0.9209 - y2_output_root_mean_squared_error: 1.5150 - val_loss: 3.8568 - val_y1_output_loss: 1.0886 - val_y2_output_loss: 2.7980 - val_y1_output_root_mean_squared_error: 1.0445 - val_y2_output_root_mean_squared_error: 1.6631
# Epoch 88/500
# 614/614 [==============================] - 0s 206us/sample - loss: 2.4534 - y1_output_loss: 0.6292 - y2_output_loss: 1.8093 - y1_output_root_mean_squared_error: 0.7941 - y2_output_root_mean_squared_error: 1.3501 - val_loss: 2.4499 - val_y1_output_loss: 0.6858 - val_y2_output_loss: 1.7137 - val_y1_output_root_mean_squared_error: 0.8402 - val_y2_output_root_mean_squared_error: 1.3206
# Epoch 89/500
# 614/614 [==============================] - 0s 203us/sample - loss: 2.5967 - y1_output_loss: 0.6751 - y2_output_loss: 1.9399 - y1_output_root_mean_squared_error: 0.8200 - y2_output_root_mean_squared_error: 1.3872 - val_loss: 7.3015 - val_y1_output_loss: 2.5678 - val_y2_output_loss: 4.7929 - val_y1_output_root_mean_squared_error: 1.6065 - val_y2_output_root_mean_squared_error: 2.1727
# Epoch 90/500
# 614/614 [==============================] - 0s 181us/sample - loss: 3.7365 - y1_output_loss: 1.1914 - y2_output_loss: 2.5199 - y1_output_root_mean_squared_error: 1.0953 - y2_output_root_mean_squared_error: 1.5927 - val_loss: 2.5902 - val_y1_output_loss: 0.6966 - val_y2_output_loss: 1.9048 - val_y1_output_root_mean_squared_error: 0.8310 - val_y2_output_root_mean_squared_error: 1.3783
# Epoch 91/500
# 614/614 [==============================] - 0s 178us/sample - loss: 2.8129 - y1_output_loss: 0.7894 - y2_output_loss: 2.0200 - y1_output_root_mean_squared_error: 0.8926 - y2_output_root_mean_squared_error: 1.4199 - val_loss: 5.2361 - val_y1_output_loss: 0.8124 - val_y2_output_loss: 4.4623 - val_y1_output_root_mean_squared_error: 0.9165 - val_y2_output_root_mean_squared_error: 2.0967
# Epoch 92/500
# 614/614 [==============================] - 0s 162us/sample - loss: 2.4677 - y1_output_loss: 0.6848 - y2_output_loss: 1.7973 - y1_output_root_mean_squared_error: 0.8111 - y2_output_root_mean_squared_error: 1.3453 - val_loss: 4.6526 - val_y1_output_loss: 1.4432 - val_y2_output_loss: 3.1608 - val_y1_output_root_mean_squared_error: 1.1905 - val_y2_output_root_mean_squared_error: 1.7987
# Epoch 93/500
# 614/614 [==============================] - 0s 170us/sample - loss: 2.4755 - y1_output_loss: 0.7649 - y2_output_loss: 1.7019 - y1_output_root_mean_squared_error: 0.8773 - y2_output_root_mean_squared_error: 1.3061 - val_loss: 3.4807 - val_y1_output_loss: 0.8892 - val_y2_output_loss: 2.5821 - val_y1_output_root_mean_squared_error: 0.9568 - val_y2_output_root_mean_squared_error: 1.6016
# Epoch 94/500
# 614/614 [==============================] - 0s 172us/sample - loss: 5.2033 - y1_output_loss: 1.5954 - y2_output_loss: 3.6027 - y1_output_root_mean_squared_error: 1.2598 - y2_output_root_mean_squared_error: 1.9016 - val_loss: 7.5487 - val_y1_output_loss: 3.0447 - val_y2_output_loss: 4.9657 - val_y1_output_root_mean_squared_error: 1.6722 - val_y2_output_root_mean_squared_error: 2.1800
# Epoch 95/500
# 614/614 [==============================] - 0s 159us/sample - loss: 3.2599 - y1_output_loss: 0.9712 - y2_output_loss: 2.3247 - y1_output_root_mean_squared_error: 0.9834 - y2_output_root_mean_squared_error: 1.5142 - val_loss: 3.4171 - val_y1_output_loss: 1.4534 - val_y2_output_loss: 1.9176 - val_y1_output_root_mean_squared_error: 1.2030 - val_y2_output_root_mean_squared_error: 1.4035
# Epoch 96/500
# 614/614 [==============================] - 0s 160us/sample - loss: 3.0512 - y1_output_loss: 0.8560 - y2_output_loss: 2.1837 - y1_output_root_mean_squared_error: 0.9286 - y2_output_root_mean_squared_error: 1.4795 - val_loss: 3.2456 - val_y1_output_loss: 0.7178 - val_y2_output_loss: 2.5263 - val_y1_output_root_mean_squared_error: 0.8588 - val_y2_output_root_mean_squared_error: 1.5837
# Epoch 97/500
# 614/614 [==============================] - 0s 171us/sample - loss: 2.0550 - y1_output_loss: 0.5234 - y2_output_loss: 1.5187 - y1_output_root_mean_squared_error: 0.7263 - y2_output_root_mean_squared_error: 1.2359 - val_loss: 2.6159 - val_y1_output_loss: 0.5904 - val_y2_output_loss: 1.9950 - val_y1_output_root_mean_squared_error: 0.7762 - val_y2_output_root_mean_squared_error: 1.4190
# Epoch 98/500
# 614/614 [==============================] - 0s 164us/sample - loss: 2.1632 - y1_output_loss: 0.5474 - y2_output_loss: 1.6107 - y1_output_root_mean_squared_error: 0.7376 - y2_output_root_mean_squared_error: 1.2724 - val_loss: 2.5539 - val_y1_output_loss: 0.7116 - val_y2_output_loss: 1.7965 - val_y1_output_root_mean_squared_error: 0.8422 - val_y2_output_root_mean_squared_error: 1.3581
# Epoch 99/500
# 614/614 [==============================] - 0s 172us/sample - loss: 2.5966 - y1_output_loss: 0.6761 - y2_output_loss: 1.9097 - y1_output_root_mean_squared_error: 0.8224 - y2_output_root_mean_squared_error: 1.3857 - val_loss: 2.6143 - val_y1_output_loss: 0.6972 - val_y2_output_loss: 1.9036 - val_y1_output_root_mean_squared_error: 0.8503 - val_y2_output_root_mean_squared_error: 1.3753
# Epoch 100/500
# 614/614 [==============================] - 0s 159us/sample - loss: 2.1790 - y1_output_loss: 0.5618 - y2_output_loss: 1.6039 - y1_output_root_mean_squared_error: 0.7512 - y2_output_root_mean_squared_error: 1.2707 - val_loss: 2.2450 - val_y1_output_loss: 0.5362 - val_y2_output_loss: 1.6977 - val_y1_output_root_mean_squared_error: 0.7326 - val_y2_output_root_mean_squared_error: 1.3070
# Epoch 101/500
# 614/614 [==============================] - 0s 165us/sample - loss: 2.1500 - y1_output_loss: 0.5441 - y2_output_loss: 1.5895 - y1_output_root_mean_squared_error: 0.7406 - y2_output_root_mean_squared_error: 1.2655 - val_loss: 4.9752 - val_y1_output_loss: 1.4266 - val_y2_output_loss: 3.6420 - val_y1_output_root_mean_squared_error: 1.1914 - val_y2_output_root_mean_squared_error: 1.8857
# Epoch 102/500
# 614/614 [==============================] - 0s 179us/sample - loss: 2.3611 - y1_output_loss: 0.5645 - y2_output_loss: 1.8045 - y1_output_root_mean_squared_error: 0.7459 - y2_output_root_mean_squared_error: 1.3434 - val_loss: 5.2461 - val_y1_output_loss: 1.5327 - val_y2_output_loss: 3.7520 - val_y1_output_root_mean_squared_error: 1.2131 - val_y2_output_root_mean_squared_error: 1.9428
# Epoch 103/500
# 614/614 [==============================] - 0s 167us/sample - loss: 3.1901 - y1_output_loss: 0.9111 - y2_output_loss: 2.2558 - y1_output_root_mean_squared_error: 0.9585 - y2_output_root_mean_squared_error: 1.5071 - val_loss: 2.4237 - val_y1_output_loss: 0.5220 - val_y2_output_loss: 1.8843 - val_y1_output_root_mean_squared_error: 0.7331 - val_y2_output_root_mean_squared_error: 1.3734
# Epoch 104/500
# 614/614 [==============================] - 0s 177us/sample - loss: 2.5918 - y1_output_loss: 0.6556 - y2_output_loss: 1.9226 - y1_output_root_mean_squared_error: 0.8111 - y2_output_root_mean_squared_error: 1.3906 - val_loss: 3.1660 - val_y1_output_loss: 0.9677 - val_y2_output_loss: 2.2266 - val_y1_output_root_mean_squared_error: 0.9646 - val_y2_output_root_mean_squared_error: 1.4952
# Epoch 105/500
# 614/614 [==============================] - 0s 167us/sample - loss: 2.6428 - y1_output_loss: 0.6849 - y2_output_loss: 1.9556 - y1_output_root_mean_squared_error: 0.8185 - y2_output_root_mean_squared_error: 1.4046 - val_loss: 4.9447 - val_y1_output_loss: 1.2816 - val_y2_output_loss: 3.6707 - val_y1_output_root_mean_squared_error: 1.1151 - val_y2_output_root_mean_squared_error: 1.9239
# Epoch 106/500
# 614/614 [==============================] - 0s 166us/sample - loss: 3.1391 - y1_output_loss: 0.7725 - y2_output_loss: 2.3426 - y1_output_root_mean_squared_error: 0.8809 - y2_output_root_mean_squared_error: 1.5373 - val_loss: 2.1642 - val_y1_output_loss: 0.5842 - val_y2_output_loss: 1.5410 - val_y1_output_root_mean_squared_error: 0.7650 - val_y2_output_root_mean_squared_error: 1.2566
# Epoch 107/500
# 614/614 [==============================] - 0s 169us/sample - loss: 2.0770 - y1_output_loss: 0.5789 - y2_output_loss: 1.4954 - y1_output_root_mean_squared_error: 0.7615 - y2_output_root_mean_squared_error: 1.2236 - val_loss: 3.4051 - val_y1_output_loss: 1.1427 - val_y2_output_loss: 2.2029 - val_y1_output_root_mean_squared_error: 1.0864 - val_y2_output_root_mean_squared_error: 1.4916
# Epoch 108/500
# 614/614 [==============================] - 0s 165us/sample - loss: 2.7244 - y1_output_loss: 0.7605 - y2_output_loss: 1.9597 - y1_output_root_mean_squared_error: 0.8736 - y2_output_root_mean_squared_error: 1.4005 - val_loss: 2.9477 - val_y1_output_loss: 0.9069 - val_y2_output_loss: 2.1098 - val_y1_output_root_mean_squared_error: 0.9372 - val_y2_output_root_mean_squared_error: 1.4385
# Epoch 109/500
# 614/614 [==============================] - 0s 171us/sample - loss: 2.4400 - y1_output_loss: 0.6446 - y2_output_loss: 1.7746 - y1_output_root_mean_squared_error: 0.8064 - y2_output_root_mean_squared_error: 1.3378 - val_loss: 2.1442 - val_y1_output_loss: 0.6349 - val_y2_output_loss: 1.4762 - val_y1_output_root_mean_squared_error: 0.7955 - val_y2_output_root_mean_squared_error: 1.2294
# Epoch 110/500
# 614/614 [==============================] - 0s 182us/sample - loss: 2.7191 - y1_output_loss: 0.6127 - y2_output_loss: 2.1027 - y1_output_root_mean_squared_error: 0.7806 - y2_output_root_mean_squared_error: 1.4525 - val_loss: 7.5604 - val_y1_output_loss: 2.3862 - val_y2_output_loss: 5.3722 - val_y1_output_root_mean_squared_error: 1.4959 - val_y2_output_root_mean_squared_error: 2.3071
# Epoch 111/500
# 614/614 [==============================] - 0s 159us/sample - loss: 3.0409 - y1_output_loss: 0.8518 - y2_output_loss: 2.1748 - y1_output_root_mean_squared_error: 0.9229 - y2_output_root_mean_squared_error: 1.4796 - val_loss: 3.6994 - val_y1_output_loss: 0.8587 - val_y2_output_loss: 2.8454 - val_y1_output_root_mean_squared_error: 0.9006 - val_y2_output_root_mean_squared_error: 1.6995
# Epoch 112/500
# 614/614 [==============================] - 0s 167us/sample - loss: 2.1476 - y1_output_loss: 0.5728 - y2_output_loss: 1.6209 - y1_output_root_mean_squared_error: 0.7490 - y2_output_root_mean_squared_error: 1.2596 - val_loss: 2.5659 - val_y1_output_loss: 0.6191 - val_y2_output_loss: 1.8717 - val_y1_output_root_mean_squared_error: 0.7894 - val_y2_output_root_mean_squared_error: 1.3938
# Epoch 113/500
# 614/614 [==============================] - 0s 172us/sample - loss: 2.0400 - y1_output_loss: 0.4864 - y2_output_loss: 1.5453 - y1_output_root_mean_squared_error: 0.6987 - y2_output_root_mean_squared_error: 1.2457 - val_loss: 2.8427 - val_y1_output_loss: 0.5566 - val_y2_output_loss: 2.2671 - val_y1_output_root_mean_squared_error: 0.7591 - val_y2_output_root_mean_squared_error: 1.5055
# Epoch 114/500
# 614/614 [==============================] - 0s 172us/sample - loss: 2.2980 - y1_output_loss: 0.5587 - y2_output_loss: 1.7247 - y1_output_root_mean_squared_error: 0.7498 - y2_output_root_mean_squared_error: 1.3175 - val_loss: 2.3806 - val_y1_output_loss: 0.6788 - val_y2_output_loss: 1.6724 - val_y1_output_root_mean_squared_error: 0.8197 - val_y2_output_root_mean_squared_error: 1.3072
# Epoch 115/500
# 614/614 [==============================] - 0s 169us/sample - loss: 1.5829 - y1_output_loss: 0.4541 - y2_output_loss: 1.1486 - y1_output_root_mean_squared_error: 0.6706 - y2_output_root_mean_squared_error: 1.0645 - val_loss: 6.8083 - val_y1_output_loss: 0.8173 - val_y2_output_loss: 5.9365 - val_y1_output_root_mean_squared_error: 0.8970 - val_y2_output_root_mean_squared_error: 2.4502
# Epoch 116/500
# 614/614 [==============================] - 0s 162us/sample - loss: 2.3949 - y1_output_loss: 0.6824 - y2_output_loss: 1.7074 - y1_output_root_mean_squared_error: 0.8231 - y2_output_root_mean_squared_error: 1.3105 - val_loss: 2.4630 - val_y1_output_loss: 0.8288 - val_y2_output_loss: 1.6294 - val_y1_output_root_mean_squared_error: 0.8930 - val_y2_output_root_mean_squared_error: 1.2906
# Epoch 117/500
# 614/614 [==============================] - 0s 165us/sample - loss: 2.9886 - y1_output_loss: 0.8496 - y2_output_loss: 2.1228 - y1_output_root_mean_squared_error: 0.9213 - y2_output_root_mean_squared_error: 1.4628 - val_loss: 2.6269 - val_y1_output_loss: 0.8419 - val_y2_output_loss: 1.8481 - val_y1_output_root_mean_squared_error: 0.8805 - val_y2_output_root_mean_squared_error: 1.3608
# Epoch 118/500
# 614/614 [==============================] - 0s 176us/sample - loss: 1.6901 - y1_output_loss: 0.4493 - y2_output_loss: 1.2495 - y1_output_root_mean_squared_error: 0.6692 - y2_output_root_mean_squared_error: 1.1145 - val_loss: 3.7562 - val_y1_output_loss: 0.9776 - val_y2_output_loss: 2.7173 - val_y1_output_root_mean_squared_error: 1.0034 - val_y2_output_root_mean_squared_error: 1.6581
# Epoch 119/500
# 614/614 [==============================] - 0s 168us/sample - loss: 2.7638 - y1_output_loss: 0.8228 - y2_output_loss: 1.9446 - y1_output_root_mean_squared_error: 0.9096 - y2_output_root_mean_squared_error: 1.3916 - val_loss: 7.3905 - val_y1_output_loss: 2.0768 - val_y2_output_loss: 5.3484 - val_y1_output_root_mean_squared_error: 1.4476 - val_y2_output_root_mean_squared_error: 2.3011
# Epoch 120/500
# 614/614 [==============================] - 0s 185us/sample - loss: 2.3884 - y1_output_loss: 0.5829 - y2_output_loss: 1.7954 - y1_output_root_mean_squared_error: 0.7634 - y2_output_root_mean_squared_error: 1.3438 - val_loss: 2.1124 - val_y1_output_loss: 0.5915 - val_y2_output_loss: 1.5346 - val_y1_output_root_mean_squared_error: 0.7485 - val_y2_output_root_mean_squared_error: 1.2459
# Epoch 121/500
# ...
# Epoch 198/500
# 614/614 [==============================] - 0s 172us/sample - loss: 1.2916 - y1_output_loss: 0.3067 - y2_output_loss: 0.9882 - y1_output_root_mean_squared_error: 0.5435 - y2_output_root_mean_squared_error: 0.9981 - val_loss: 3.2882 - val_y1_output_loss: 1.0914 - val_y2_output_loss: 2.2601 - val_y1_output_root_mean_squared_error: 1.0139 - val_y2_output_root_mean_squared_error: 1.5034
# Epoch 199/500
# 614/614 [==============================] - 0s 173us/sample - loss: 1.1206 - y1_output_loss: 0.2435 - y2_output_loss: 0.8806 - y1_output_root_mean_squared_error: 0.4952 - y2_output_root_mean_squared_error: 0.9356 - val_loss: 2.0531 - val_y1_output_loss: 0.4397 - val_y2_output_loss: 1.5558 - val_y1_output_root_mean_squared_error: 0.6683 - val_y2_output_root_mean_squared_error: 1.2675
# Epoch 200/500
# 614/614 [==============================] - 0s 177us/sample - loss: 1.3301 - y1_output_loss: 0.3064 - y2_output_loss: 1.0443 - y1_output_root_mean_squared_error: 0.5391 - y2_output_root_mean_squared_error: 1.0195 - val_loss: 5.1846 - val_y1_output_loss: 2.8023 - val_y2_output_loss: 2.3439 - val_y1_output_root_mean_squared_error: 1.6783 - val_y2_output_root_mean_squared_error: 1.5388
# Epoch 201/500
# 614/614 [==============================] - 0s 214us/sample - loss: 1.1508 - y1_output_loss: 0.2357 - y2_output_loss: 0.9131 - y1_output_root_mean_squared_error: 0.4854 - y2_output_root_mean_squared_error: 0.9567 - val_loss: 1.9166 - val_y1_output_loss: 0.5166 - val_y2_output_loss: 1.3554 - val_y1_output_root_mean_squared_error: 0.7212 - val_y2_output_root_mean_squared_error: 1.1817
# Epoch 202/500
# 614/614 [==============================] - 0s 200us/sample - loss: 1.0429 - y1_output_loss: 0.2776 - y2_output_loss: 0.7618 - y1_output_root_mean_squared_error: 0.5255 - y2_output_root_mean_squared_error: 0.8757 - val_loss: 1.4534 - val_y1_output_loss: 0.2370 - val_y2_output_loss: 1.1925 - val_y1_output_root_mean_squared_error: 0.4948 - val_y2_output_root_mean_squared_error: 1.0993
# Epoch 203/500
# 614/614 [==============================] - 0s 193us/sample - loss: 1.8120 - y1_output_loss: 0.5852 - y2_output_loss: 1.2134 - y1_output_root_mean_squared_error: 0.7683 - y2_output_root_mean_squared_error: 1.1053 - val_loss: 2.1511 - val_y1_output_loss: 0.6168 - val_y2_output_loss: 1.5069 - val_y1_output_root_mean_squared_error: 0.7888 - val_y2_output_root_mean_squared_error: 1.2365
# Epoch 204/500
# 614/614 [==============================] - 0s 197us/sample - loss: 1.3641 - y1_output_loss: 0.3065 - y2_output_loss: 1.0450 - y1_output_root_mean_squared_error: 0.5559 - y2_output_root_mean_squared_error: 1.0271 - val_loss: 1.8841 - val_y1_output_loss: 0.4747 - val_y2_output_loss: 1.4023 - val_y1_output_root_mean_squared_error: 0.6782 - val_y2_output_root_mean_squared_error: 1.1934
# Epoch 205/500
# 614/614 [==============================] - 0s 226us/sample - loss: 1.0726 - y1_output_loss: 0.2299 - y2_output_loss: 0.8358 - y1_output_root_mean_squared_error: 0.4795 - y2_output_root_mean_squared_error: 0.9180 - val_loss: 1.8573 - val_y1_output_loss: 0.3123 - val_y2_output_loss: 1.5006 - val_y1_output_root_mean_squared_error: 0.5686 - val_y2_output_root_mean_squared_error: 1.2386
# Epoch 206/500
# 614/614 [==============================] - 0s 191us/sample - loss: 1.1735 - y1_output_loss: 0.2622 - y2_output_loss: 0.9060 - y1_output_root_mean_squared_error: 0.5131 - y2_output_root_mean_squared_error: 0.9541 - val_loss: 1.6162 - val_y1_output_loss: 0.3979 - val_y2_output_loss: 1.2198 - val_y1_output_root_mean_squared_error: 0.6153 - val_y2_output_root_mean_squared_error: 1.1125
# Epoch 207/500
# 614/614 [==============================] - 0s 183us/sample - loss: 1.0070 - y1_output_loss: 0.2170 - y2_output_loss: 0.7861 - y1_output_root_mean_squared_error: 0.4673 - y2_output_root_mean_squared_error: 0.8881 - val_loss: 1.2668 - val_y1_output_loss: 0.2572 - val_y2_output_loss: 0.9660 - val_y1_output_root_mean_squared_error: 0.5146 - val_y2_output_root_mean_squared_error: 1.0010
# Epoch 208/500
# 614/614 [==============================] - 0s 179us/sample - loss: 2.5889 - y1_output_loss: 0.5715 - y2_output_loss: 1.9963 - y1_output_root_mean_squared_error: 0.7577 - y2_output_root_mean_squared_error: 1.4194 - val_loss: 1.7694 - val_y1_output_loss: 0.3095 - val_y2_output_loss: 1.4177 - val_y1_output_root_mean_squared_error: 0.5651 - val_y2_output_root_mean_squared_error: 1.2042
# Epoch 209/500
# 614/614 [==============================] - 0s 201us/sample - loss: 0.9523 - y1_output_loss: 0.2325 - y2_output_loss: 0.7118 - y1_output_root_mean_squared_error: 0.4839 - y2_output_root_mean_squared_error: 0.8475 - val_loss: 1.2492 - val_y1_output_loss: 0.2221 - val_y2_output_loss: 0.9969 - val_y1_output_root_mean_squared_error: 0.4731 - val_y2_output_root_mean_squared_error: 1.0126
# Epoch 210/500
# 614/614 [==============================] - 0s 217us/sample - loss: 1.1747 - y1_output_loss: 0.2258 - y2_output_loss: 0.9847 - y1_output_root_mean_squared_error: 0.4735 - y2_output_root_mean_squared_error: 0.9749 - val_loss: 7.4832 - val_y1_output_loss: 0.8079 - val_y2_output_loss: 6.6449 - val_y1_output_root_mean_squared_error: 0.9088 - val_y2_output_root_mean_squared_error: 2.5802
# Epoch 211/500
# 614/614 [==============================] - 0s 179us/sample - loss: 1.5972 - y1_output_loss: 0.3262 - y2_output_loss: 1.2612 - y1_output_root_mean_squared_error: 0.5711 - y2_output_root_mean_squared_error: 1.1274 - val_loss: 1.9871 - val_y1_output_loss: 0.6302 - val_y2_output_loss: 1.3107 - val_y1_output_root_mean_squared_error: 0.8002 - val_y2_output_root_mean_squared_error: 1.1605
# Epoch 212/500
# 614/614 [==============================] - 0s 195us/sample - loss: 1.0997 - y1_output_loss: 0.2227 - y2_output_loss: 0.8721 - y1_output_root_mean_squared_error: 0.4732 - y2_output_root_mean_squared_error: 0.9358 - val_loss: 1.2017 - val_y1_output_loss: 0.2010 - val_y2_output_loss: 0.9874 - val_y1_output_root_mean_squared_error: 0.4486 - val_y2_output_root_mean_squared_error: 1.0002
# Epoch 213/500
# 614/614 [==============================] - 0s 181us/sample - loss: 0.9914 - y1_output_loss: 0.2274 - y2_output_loss: 0.7563 - y1_output_root_mean_squared_error: 0.4787 - y2_output_root_mean_squared_error: 0.8731 - val_loss: 1.3042 - val_y1_output_loss: 0.2085 - val_y2_output_loss: 1.0656 - val_y1_output_root_mean_squared_error: 0.4575 - val_y2_output_root_mean_squared_error: 1.0464
# Epoch 214/500
# 614/614 [==============================] - 0s 205us/sample - loss: 0.9717 - y1_output_loss: 0.2199 - y2_output_loss: 0.7523 - y1_output_root_mean_squared_error: 0.4705 - y2_output_root_mean_squared_error: 0.8662 - val_loss: 1.2228 - val_y1_output_loss: 0.2054 - val_y2_output_loss: 0.9858 - val_y1_output_root_mean_squared_error: 0.4579 - val_y2_output_root_mean_squared_error: 1.0066
# Epoch 215/500
# 614/614 [==============================] - 0s 222us/sample - loss: 1.0944 - y1_output_loss: 0.2512 - y2_output_loss: 0.8468 - y1_output_root_mean_squared_error: 0.5022 - y2_output_root_mean_squared_error: 0.9177 - val_loss: 4.8941 - val_y1_output_loss: 1.7432 - val_y2_output_loss: 3.3687 - val_y1_output_root_mean_squared_error: 1.2734 - val_y2_output_root_mean_squared_error: 1.8090
# Epoch 216/500
# 614/614 [==============================] - 0s 203us/sample - loss: 1.1647 - y1_output_loss: 0.2280 - y2_output_loss: 0.9322 - y1_output_root_mean_squared_error: 0.4795 - y2_output_root_mean_squared_error: 0.9668 - val_loss: 1.6574 - val_y1_output_loss: 0.2884 - val_y2_output_loss: 1.3751 - val_y1_output_root_mean_squared_error: 0.5227 - val_y2_output_root_mean_squared_error: 1.1765
# Epoch 217/500
# 614/614 [==============================] - 0s 177us/sample - loss: 1.0244 - y1_output_loss: 0.2290 - y2_output_loss: 0.7932 - y1_output_root_mean_squared_error: 0.4796 - y2_output_root_mean_squared_error: 0.8913 - val_loss: 1.5178 - val_y1_output_loss: 0.2465 - val_y2_output_loss: 1.2221 - val_y1_output_root_mean_squared_error: 0.5025 - val_y2_output_root_mean_squared_error: 1.1248
# Epoch 218/500
# 614/614 [==============================] - 0s 222us/sample - loss: 0.9381 - y1_output_loss: 0.2386 - y2_output_loss: 0.7144 - y1_output_root_mean_squared_error: 0.4887 - y2_output_root_mean_squared_error: 0.8362 - val_loss: 3.7728 - val_y1_output_loss: 0.3513 - val_y2_output_loss: 3.3790 - val_y1_output_root_mean_squared_error: 0.5976 - val_y2_output_root_mean_squared_error: 1.8482
# Epoch 219/500
# 614/614 [==============================] - 0s 200us/sample - loss: 1.0048 - y1_output_loss: 0.2566 - y2_output_loss: 0.7434 - y1_output_root_mean_squared_error: 0.5062 - y2_output_root_mean_squared_error: 0.8652 - val_loss: 1.2353 - val_y1_output_loss: 0.2304 - val_y2_output_loss: 0.9650 - val_y1_output_root_mean_squared_error: 0.4873 - val_y2_output_root_mean_squared_error: 0.9989
# Epoch 220/500
# 614/614 [==============================] - 0s 186us/sample - loss: 1.3069 - y1_output_loss: 0.2798 - y2_output_loss: 1.1368 - y1_output_root_mean_squared_error: 0.5058 - y2_output_root_mean_squared_error: 1.0252 - val_loss: 21.6914 - val_y1_output_loss: 8.9537 - val_y2_output_loss: 13.9176 - val_y1_output_root_mean_squared_error: 2.8862 - val_y2_output_root_mean_squared_error: 3.6553
# Epoch 221/500
# 614/614 [==============================] - 0s 173us/sample - loss: 3.0836 - y1_output_loss: 0.7812 - y2_output_loss: 2.4028 - y1_output_root_mean_squared_error: 0.8769 - y2_output_root_mean_squared_error: 1.5214 - val_loss: 11.0137 - val_y1_output_loss: 1.0344 - val_y2_output_loss: 9.9436 - val_y1_output_root_mean_squared_error: 1.0060 - val_y2_output_root_mean_squared_error: 3.1625
# Epoch 222/500
# 614/614 [==============================] - 0s 171us/sample - loss: 1.8284 - y1_output_loss: 0.4016 - y2_output_loss: 1.4226 - y1_output_root_mean_squared_error: 0.6314 - y2_output_root_mean_squared_error: 1.1957 - val_loss: 1.5509 - val_y1_output_loss: 0.3023 - val_y2_output_loss: 1.2110 - val_y1_output_root_mean_squared_error: 0.5521 - val_y2_output_root_mean_squared_error: 1.1163
# Epoch 223/500
# 614/614 [==============================] - 0s 191us/sample - loss: 0.8910 - y1_output_loss: 0.1986 - y2_output_loss: 0.6862 - y1_output_root_mean_squared_error: 0.4457 - y2_output_root_mean_squared_error: 0.8320 - val_loss: 1.3172 - val_y1_output_loss: 0.2585 - val_y2_output_loss: 1.0368 - val_y1_output_root_mean_squared_error: 0.5094 - val_y2_output_root_mean_squared_error: 1.0284
# Epoch 224/500
# 614/614 [==============================] - 0s 195us/sample - loss: 0.9848 - y1_output_loss: 0.2275 - y2_output_loss: 0.7541 - y1_output_root_mean_squared_error: 0.4783 - y2_output_root_mean_squared_error: 0.8695 - val_loss: 1.9660 - val_y1_output_loss: 0.4586 - val_y2_output_loss: 1.4723 - val_y1_output_root_mean_squared_error: 0.6767 - val_y2_output_root_mean_squared_error: 1.2280
# Epoch 225/500
# 614/614 [==============================] - 0s 169us/sample - loss: 0.8532 - y1_output_loss: 0.1977 - y2_output_loss: 0.6496 - y1_output_root_mean_squared_error: 0.4456 - y2_output_root_mean_squared_error: 0.8091 - val_loss: 1.3218 - val_y1_output_loss: 0.2311 - val_y2_output_loss: 1.0671 - val_y1_output_root_mean_squared_error: 0.4800 - val_y2_output_root_mean_squared_error: 1.0447
# Epoch 226/500
# 614/614 [==============================] - 0s 170us/sample - loss: 1.5361 - y1_output_loss: 0.3200 - y2_output_loss: 1.2079 - y1_output_root_mean_squared_error: 0.5657 - y2_output_root_mean_squared_error: 1.1027 - val_loss: 1.4344 - val_y1_output_loss: 0.3981 - val_y2_output_loss: 1.0274 - val_y1_output_root_mean_squared_error: 0.6176 - val_y2_output_root_mean_squared_error: 1.0261
# Epoch 227/500
# 614/614 [==============================] - 0s 159us/sample - loss: 1.1550 - y1_output_loss: 0.2325 - y2_output_loss: 0.9133 - y1_output_root_mean_squared_error: 0.4835 - y2_output_root_mean_squared_error: 0.9598 - val_loss: 1.1330 - val_y1_output_loss: 0.2182 - val_y2_output_loss: 0.8966 - val_y1_output_root_mean_squared_error: 0.4642 - val_y2_output_root_mean_squared_error: 0.9579
# Epoch 228/500
# 614/614 [==============================] - 0s 183us/sample - loss: 0.9116 - y1_output_loss: 0.1851 - y2_output_loss: 0.7445 - y1_output_root_mean_squared_error: 0.4311 - y2_output_root_mean_squared_error: 0.8519 - val_loss: 3.8246 - val_y1_output_loss: 0.3040 - val_y2_output_loss: 3.5549 - val_y1_output_root_mean_squared_error: 0.5362 - val_y2_output_root_mean_squared_error: 1.8807
# Epoch 229/500
# 614/614 [==============================] - 0s 185us/sample - loss: 0.9098 - y1_output_loss: 0.1793 - y2_output_loss: 0.7452 - y1_output_root_mean_squared_error: 0.4233 - y2_output_root_mean_squared_error: 0.8548 - val_loss: 2.6770 - val_y1_output_loss: 0.3662 - val_y2_output_loss: 2.2828 - val_y1_output_root_mean_squared_error: 0.6148 - val_y2_output_root_mean_squared_error: 1.5163
# Epoch 230/500
# 614/614 [==============================] - 0s 195us/sample - loss: 1.0784 - y1_output_loss: 0.2630 - y2_output_loss: 0.8144 - y1_output_root_mean_squared_error: 0.5094 - y2_output_root_mean_squared_error: 0.9050 - val_loss: 1.2197 - val_y1_output_loss: 0.3251 - val_y2_output_loss: 0.8772 - val_y1_output_root_mean_squared_error: 0.5639 - val_y2_output_root_mean_squared_error: 0.9496
# Epoch 231/500
# 614/614 [==============================] - 0s 178us/sample - loss: 1.1628 - y1_output_loss: 0.2560 - y2_output_loss: 0.9045 - y1_output_root_mean_squared_error: 0.5064 - y2_output_root_mean_squared_error: 0.9520 - val_loss: 2.1786 - val_y1_output_loss: 0.3263 - val_y2_output_loss: 1.8135 - val_y1_output_root_mean_squared_error: 0.5790 - val_y2_output_root_mean_squared_error: 1.3577
# Epoch 232/500
# 614/614 [==============================] - 0s 172us/sample - loss: 1.2180 - y1_output_loss: 0.2700 - y2_output_loss: 0.9385 - y1_output_root_mean_squared_error: 0.5214 - y2_output_root_mean_squared_error: 0.9727 - val_loss: 1.1176 - val_y1_output_loss: 0.1847 - val_y2_output_loss: 0.9101 - val_y1_output_root_mean_squared_error: 0.4282 - val_y2_output_root_mean_squared_error: 0.9666
# Epoch 233/500
# 614/614 [==============================] - 0s 191us/sample - loss: 0.9882 - y1_output_loss: 0.2569 - y2_output_loss: 0.7389 - y1_output_root_mean_squared_error: 0.5035 - y2_output_root_mean_squared_error: 0.8571 - val_loss: 1.7553 - val_y1_output_loss: 0.2736 - val_y2_output_loss: 1.4489 - val_y1_output_root_mean_squared_error: 0.5257 - val_y2_output_root_mean_squared_error: 1.2161
# Epoch 234/500
# 614/614 [==============================] - 0s 178us/sample - loss: 0.8553 - y1_output_loss: 0.2065 - y2_output_loss: 0.6440 - y1_output_root_mean_squared_error: 0.4545 - y2_output_root_mean_squared_error: 0.8055 - val_loss: 1.1763 - val_y1_output_loss: 0.1855 - val_y2_output_loss: 0.9570 - val_y1_output_root_mean_squared_error: 0.4311 - val_y2_output_root_mean_squared_error: 0.9952
# Epoch 235/500
# 614/614 [==============================] - 0s 184us/sample - loss: 1.4450 - y1_output_loss: 0.2778 - y2_output_loss: 1.1543 - y1_output_root_mean_squared_error: 0.5292 - y2_output_root_mean_squared_error: 1.0794 - val_loss: 1.1992 - val_y1_output_loss: 0.3047 - val_y2_output_loss: 0.9055 - val_y1_output_root_mean_squared_error: 0.5332 - val_y2_output_root_mean_squared_error: 0.9565
# Epoch 236/500
# 614/614 [==============================] - 0s 186us/sample - loss: 0.8556 - y1_output_loss: 0.1967 - y2_output_loss: 0.6675 - y1_output_root_mean_squared_error: 0.4448 - y2_output_root_mean_squared_error: 0.8110 - val_loss: 1.2670 - val_y1_output_loss: 0.2540 - val_y2_output_loss: 0.9706 - val_y1_output_root_mean_squared_error: 0.5125 - val_y2_output_root_mean_squared_error: 1.0022
# Epoch 237/500
#  10/614 [..............................] - ETA: 0s - loss: 1.2960 - y1_output_loss: 0.3315 - y2_output_loss: 0.9645 - y1_output_root_mean_squared_error: 0.5757 - y2_output_root_mean_squared_error: 0.9821

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 36us/sample - loss: 1.5585 - y1_output_loss: 0.2494 - y2_output_loss: 1.2844 - y1_output_root_mean_squared_error: 0.5014 - y2_output_root_mean_squared_error: 1.1433
# Loss = 1.5584885145162608, Y1_loss = 0.24938121438026428, Y1_mse = 0.5013816952705383, Y2_loss = 1.2843844890594482, Y2_mse = 1.1432868242263794

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
