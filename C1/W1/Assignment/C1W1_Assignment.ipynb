# %% [markdown]
# # Week 1: Multiple Output Models using the Keras Functional API
#
# Welcome to the first programming assignment of the course! Your task will be to use the Keras functional API to train a model to predict two outputs. For this lab, you will use the **[Wine Quality Dataset](https://archive.ics.uci.edu/ml/datasets/Wine+Quality)** from the **UCI machine learning repository**. It has separate datasets for red wine and white wine.
#
# Normally, the wines are classified into one of the quality ratings specified in the attributes. In this exercise, you will combine the two datasets to predict the wine quality and whether the wine is red or white solely from the attributes.
#
# You will model wine quality estimations as a regression problem and wine type detection as a binary classification problem.
#
# #### Please complete sections that are marked **(TODO)**

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import itertools
import utils

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import itertools

import utils

# %% [markdown]
# ## Load Dataset
#
#
# You will now load the dataset from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/index.php) which are **already saved** in your workspace (*Note: For successful grading, please **do not** modify the default string set to the `URI` variable below*).
#
# ### Pre-process the white wine dataset (TODO)
# You will add a new column named `is_red` in your dataframe to indicate if the wine is white or red.
# - In the white wine dataset, you will fill the column `is_red` with  zeros (0).

# %%
URI = './winequality-white.csv'

white_df = pd.read_csv(URI, sep=";")

white_df["is_red"] = 0

white_df = white_df.drop_duplicates(keep='first')

# %%
## Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
## You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



# # URL of the white wine dataset
URI = './winequality-white.csv'

# # load the dataset from the URL
white_df = pd.read_csv(URI, sep=";")

# # fill the `is_red` column with zeros.
white_df["is_red"] = 0 # YOUR CODE HERE

# # keep only the first of duplicate items
white_df = white_df.drop_duplicates(keep='first')

# %%
# You can click `File -> Open` in the menu above and open the `utils.py` file 
# in case you want to inspect the unit tests being used for each graded function.

utils.test_white_df(white_df)
# Out:
#  All public tests passed

# %%
print(white_df.alcohol[0])
print(white_df.alcohol[100])

# EXPECTED OUTPUT
# 8.8
# 9.1
# Out:
# 8.8
# 9.1

# %% [markdown]
# ### Pre-process the red wine dataset (TODO)
# - In the red wine dataset, you will fill in the column `is_red` with ones (1).

# %%
## Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
## You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



# # URL of the red wine dataset
URI = './winequality-red.csv'

# # load the dataset from the URL
red_df = pd.read_csv(URI, sep=";")

# # fill the `is_red` column with ones.
red_df["is_red"] = 1 # YOUR CODE HERE

# # keep only the first of duplicate items
red_df = red_df.drop_duplicates(keep='first')

# %%
utils.test_red_df(red_df)
# Out:
#  All public tests passed

# %%
print(red_df.alcohol[0])
print(red_df.alcohol[100])

# EXPECTED OUTPUT
# 9.4
# 10.2
# Out:
# 9.4
# 10.2

# %% [markdown]
# ### Concatenate the datasets
#
# Next, concatenate the red and white wine dataframes.

# %%
df = pd.concat([red_df, white_df], ignore_index=True)

# %%
print(df.alcohol[0])
print(df.alcohol[100])

# EXPECTED OUTPUT
# 9.4
# 9.5
# Out:
# 9.4
# 9.5

# %% [markdown]
# In a real-world scenario, you should shuffle the data. For this assignment however, **you are not** going to do that because the grader needs to test with deterministic data. If you want the code to do it **after** you've gotten your grade for this notebook, we left the commented line below for reference

# %%
#df = df.iloc[np.random.permutation(len(df))]

# %% [markdown]
# This will chart the quality of the wines.

# %%
df['quality'].hist(bins=20);

# %% [markdown]
# ### Imbalanced data (TODO)
# You can see from the plot above that the wine quality dataset is imbalanced.
# - Since there are very few observations with quality equal to 3, 4, 8 and 9, you can drop these observations from your dataset.
# - You can do this by removing data belonging to all classes except those > 4 and < 8.

# %%
## Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
## You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



# # get data with wine quality greater than 4 and less than 8
df = df[(df['quality'] > 4) & (df['quality'] < 8 )]

# # reset index and drop the old one
df = df.reset_index(drop=True)

# %%
utils.test_df_drop(df)
# Out:
#  All public tests passed

# %%
print(df.alcohol[0])
print(df.alcohol[100])

# EXPECTED OUTPUT
# 9.4
# 10.9
# Out:
# 9.4
# 10.9

# %% [markdown]
# You can plot again to see the new range of data and quality

# %%
df['quality'].hist(bins=20);

# %% [markdown]
# ### Train Test Split (TODO)
#
# Next, you can split the datasets into training, test and validation datasets.
# - The data frame should be split 80:20 into `train` and `test` sets.
# - The resulting `train` should then be split 80:20 into `train` and `val` sets.
# - The `train_test_split` parameter `test_size` takes a float value that ranges between 0. and 1, and represents the proportion of the dataset that is allocated to the test set.  The rest of the data is allocated to the training set.

# %%
train, test = train_test_split(df, test_size = 0.2, random_state = 1)

train, val = train_test_split(train, test_size =0.2, random_state = 1)

# %%
# Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
# You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



# Please do not change the random_state parameter. This is needed for grading.

# split df into 80:20 train and test sets
train, test = train_test_split(df, test_size=0.2 , random_state = 1)
                               
# split train into 80:20 train and val sets
train, val = train_test_split(train, test_size=0.2, random_state = 1)

# %%
utils.test_data_sizes(train.size, test.size, val.size)
# Out:
#  All public tests passed

# %% [markdown]
# Here's where you can explore the training stats. You can pop the labels 'is_red' and 'quality' from the data as these will be used as the labels

# %%
train_stats = train.describe()
train_stats.pop('is_red')
train_stats.pop('quality')
train_stats = train_stats.transpose()

# %% [markdown]
# Explore the training stats!

# %%
train_stats
# Out:
#                        count        mean        std      min       25%  \
# fixed acidity         3155.0    7.221616   1.325297  3.80000   6.40000
# volatile acidity      3155.0    0.338929   0.162476  0.08000   0.23000
# citric acid           3155.0    0.321569   0.147970  0.00000   0.25000
# residual sugar        3155.0    5.155911   4.639632  0.60000   1.80000
# chlorides             3155.0    0.056976   0.036802  0.01200   0.03800
# free sulfur dioxide   3155.0   30.388590  17.236784  1.00000  17.00000
# total sulfur dioxide  3155.0  115.062282  56.706617  6.00000  75.00000
# density               3155.0    0.994633   0.003005  0.98711   0.99232
# pH                    3155.0    3.223201   0.161272  2.72000   3.11000
# sulphates             3155.0    0.534051   0.149149  0.22000   0.43000
# alcohol               3155.0   10.504466   1.154654  8.50000   9.50000
#
#                             50%       75%        max
# fixed acidity           7.00000    7.7000   15.60000
# volatile acidity        0.29000    0.4000    1.24000
# citric acid             0.31000    0.4000    1.66000
# residual sugar          2.80000    7.6500   65.80000
# chlorides               0.04700    0.0660    0.61100
# free sulfur dioxide    28.00000   41.0000  131.00000
# total sulfur dioxide  117.00000  156.0000  344.00000
# density                 0.99481    0.9968    1.03898
# pH                      3.21000    3.3300    4.01000
# sulphates               0.51000    0.6000    1.95000
# alcohol                10.30000   11.3000   14.00000

# %% [markdown]
# ### Get the labels (TODO)
#
# The features and labels are currently in the same dataframe.
# - You will want to store the label columns `is_red` and `quality` separately from the feature columns.
# - The following function, `format_output`, gets these two columns from the dataframe (it's given to you).
# - `format_output` also formats the data into numpy arrays.
# - Please use the `format_output` and apply it to the `train`, `val` and `test` sets to get dataframes for the labels.

# %%
def format_output(data):
    is_red = data.pop('is_red')
    is_red = np.array(is_red)
    quality = data.pop('quality')
    quality = np.array(quality)
    return (quality, is_red)

# %%
# Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
# You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



# format the output of the train set
train_Y = format_output(train)

# format the output of the val set
val_Y = format_output(val)
    
# format the output of the test set
test_Y = format_output(test)

# %%
utils.test_format_output(df, train_Y, val_Y, test_Y)
# Out:
#  All public tests passed

# %% [markdown]
# Notice that after you get the labels, the `train`, `val` and `test` dataframes no longer contain the label columns, and contain just the feature columns.
# - This is because you used `.pop` in the `format_output` function.

# %%
train.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 225             7.5              0.65         0.18             7.0      0.088
# 3557            6.3              0.27         0.29            12.2      0.044
# 3825            8.8              0.27         0.25             5.0      0.024
# 1740            6.4              0.45         0.07             1.1      0.030
# 1221            7.2              0.53         0.13             2.0      0.058
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 225                  27.0                  94.0  0.99915  3.38       0.77
# 3557                 59.0                 196.0  0.99782  3.14       0.40
# 3825                 52.0                  99.0  0.99250  2.87       0.49
# 1740                 10.0                 131.0  0.99050  2.97       0.28
# 1221                 18.0                  22.0  0.99573  3.21       0.68
#
#       alcohol
# 225       9.4
# 3557      8.8
# 3825     11.4
# 1740     10.8
# 1221      9.9

# %% [markdown]
# ### Normalize the data (TODO)
#
# Next, you can normalize the data, x, using the formula:
# $$x_{norm} = \frac{x - \mu}{\sigma}$$
# - The `norm` function is defined for you.
# - Please apply the `norm` function to normalize the dataframes that contains the feature columns of `train`, `val` and `test` sets.

# %%
def norm(x):
    return (x - train_stats['mean']) / train_stats['std']

# %%
def norm(x):
    return (x - train_stats['mean']) / train_stats['std']

# %%
# Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
# You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



# normalize the train set
norm_train_X = norm(train)
    
# normalize the val set
norm_val_X = norm(val)
    
# normalize the test set
norm_test_X = norm(test)

# %%
utils.test_norm(norm_train_X, norm_val_X, norm_test_X, train, val, test)
# Out:
#  All public tests passed

# %% [markdown]
# ## Define the Model (TODO)
#
# Define the model using the functional API. The base model will be 2 `Dense` layers of 128 neurons each, and have the `'relu'` activation.
# - Check out the documentation for [tf.keras.layers.Dense](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense)

# %%
# Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
# You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



def base_model(inputs):
    
    # connect a Dense layer with 128 neurons and a relu activation
    x = Dense(128, activation='relu')(inputs)
    
    # connect another Dense layer with 128 neurons and a relu activation
    x = Dense(128, activation='relu')(x)
    return x

# %%
utils.test_base_model(base_model)
# Out:
#  All public tests passed

# %% [markdown]
# # Define output layers of the model (TODO)
#
# You will add output layers to the base model.
# - The model will need two outputs.
#
# One output layer will predict wine quality, which is a numeric value.
# - Define a `Dense` layer with 1 neuron.
# - Since this is a regression output, the activation can be left as its default value `None`.
#
# The other output layer will predict the wine type, which is either red `1` or not red `0` (white).
# - Define a `Dense` layer with 1 neuron.
# - Since there are two possible categories, you can use a sigmoid activation for binary classification.
#
# Define the `Model`
# - Define the `Model` object, and set the following parameters:
#   - `inputs`: pass in the inputs to the model as a list.
#   - `outputs`: pass in a list of the outputs that you just defined: wine quality, then wine type.
#   - **Note**: please list the wine quality before wine type in the outputs, as this will affect the calculated loss if you choose the other order.

# %%
def final_model(inputs):
    x = base_model(inputs)
    
    output_1 = Dense(1, activation = 'None')(x)
    
    output_2 = Dense(1, activation = 'sigmoid')(x)
    
    model = Model(inputs = inputs, outputs = [output_1, output_2])
    
    return model

# %%
# Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
# You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



def final_model(inputs):
    
    # get the base model
    x = base_model(inputs)

    # connect the output Dense layer for regression
    wine_quality = Dense(units='1', name='wine_quality')(x)

    # connect the output Dense layer for classification. this will use a sigmoid activation.
    wine_type = Dense(units='1', activation='sigmoid', name='wine_type')(x)

    # define the model using the input and output layers
    model = Model(inputs=inputs,  outputs=[wine_quality, wine_type])

    return model

# %%
utils.test_final_model(final_model)
# Out:
#  All public tests passed

# %% [markdown]
# ## Compiling the Model
#
# Next, compile the model. When setting the loss parameter of `model.compile`, you're setting the loss for each of the two outputs (wine quality and wine type).
#
# To set more than one loss, use a dictionary of key-value pairs.
# - You can look at the docs for the losses [here](https://www.tensorflow.org/api_docs/python/tf/keras/losses#functions).
#     - **Note**: For the desired spelling, please look at the "Functions" section of the documentation and not the "classes" section on that same page.
# - wine_type: Since you will be performing binary classification on wine type, you should use the binary crossentropy loss function for it.  Please pass this in as a string.
#   - **Hint**, this should be all lowercase.  In the documentation, you'll see this under the "Functions" section, not the "Classes" section.
# - wine_quality: since this is a regression output, use the mean squared error.  Please pass it in as a string, all lowercase.
#   - **Hint**: You may notice that there are two aliases for mean squared error.  Please use the shorter name.
#
#
# You will also set the metric for each of the two outputs.  Again, to set metrics for two or more outputs, use a dictionary with key value pairs.
# - The metrics documentation is linked [here](https://www.tensorflow.org/api_docs/python/tf/keras/metrics).
# - For the wine type, please set it to accuracy as a string, all lowercase.
# - For wine quality, please use the root mean squared error.  Instead of a string, you'll set it to an instance of the class [RootMeanSquaredError](https://www.tensorflow.org/api_docs/python/tf/keras/metrics/RootMeanSquaredError), which belongs to the tf.keras.metrics module.
#
# **Note**: If you see the error message
# >Exception: wine quality loss function is incorrect.
#
# - Please also check your other losses and metrics, as the error may be caused by the other three key-value pairs and not the wine quality loss.

# %%
inputs = tf.keras.layers.Input(shape=(11,))
rms = tf.keras.optimizers.RMSprop(lr = 0.0001)
model = final_model(inputs)

model.compile(optimizer = rms,
             loss = {'wine_type': 'binary_crossentropy',
                    'wine_quality': 'mse'},
             metrics = {'wine_type': 'accuracy',
                        'wine_quality': tf.keras.metrics.RootMeanSquaredError()
                       })

# %%
# Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
# You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



inputs = tf.keras.layers.Input(shape=(11,))
rms = tf.keras.optimizers.RMSprop(lr=0.0001)
model = final_model(inputs)

model.compile(optimizer=rms, 
              loss = {'wine_type' : 'binary_crossentropy',
                      'wine_quality' : 'mse'
                     },
              metrics = {'wine_type' : 'accuracy',
                         'wine_quality': tf.keras.metrics.RootMeanSquaredError()
                       }
             )

# %%
utils.test_model_compile(model)
# Out:
#  All public tests passed

# %% [markdown]
# ## Training the Model (TODO)
#
# Fit the model to the training inputs and outputs.
# - Check the documentation for [model.fit](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit).
# - Remember to use the normalized training set as inputs.
# - For the validation data, please use the normalized validation set.
#
# **Important: Please do not increase the number of epochs below. This is to avoid the grader from timing out. You can increase it once you have submitted your work.**

# %%
history = model.fit(norm_train_X, train_Y, epochs = 40, validation_data = (norm_val_X, val_Y))
# Out:
# Train on 3155 samples, validate on 789 samples
# Epoch 1/40
# 3155/3155 [==============================] - 1s 412us/sample - loss: 26.7605 - wine_quality_loss: 26.0658 - wine_type_loss: 0.6566 - wine_quality_root_mean_squared_error: 5.1092 - wine_type_accuracy: 0.6761 - val_loss: 19.4111 - val_wine_quality_loss: 18.8059 - val_wine_type_loss: 0.6245 - val_wine_quality_root_mean_squared_error: 4.3343 - val_wine_type_accuracy: 0.7985
# Epoch 2/40
# 3155/3155 [==============================] - 0s 118us/sample - loss: 13.4913 - wine_quality_loss: 12.8779 - wine_type_loss: 0.5918 - wine_quality_root_mean_squared_error: 3.5916 - wine_type_accuracy: 0.7870 - val_loss: 8.4406 - val_wine_quality_loss: 7.9586 - val_wine_type_loss: 0.5622 - val_wine_quality_root_mean_squared_error: 2.8069 - val_wine_type_accuracy: 0.7440
# Epoch 3/40
# 3155/3155 [==============================] - 0s 118us/sample - loss: 5.8136 - wine_quality_loss: 5.2883 - wine_type_loss: 0.5186 - wine_quality_root_mean_squared_error: 2.3010 - wine_type_accuracy: 0.7559 - val_loss: 3.7607 - val_wine_quality_loss: 3.3823 - val_wine_type_loss: 0.4776 - val_wine_quality_root_mean_squared_error: 1.8119 - val_wine_type_accuracy: 0.7630
# Epoch 4/40
# 3155/3155 [==============================] - 0s 100us/sample - loss: 3.3384 - wine_quality_loss: 2.9084 - wine_type_loss: 0.4257 - wine_quality_root_mean_squared_error: 1.7066 - wine_type_accuracy: 0.8130 - val_loss: 2.7047 - val_wine_quality_loss: 2.3872 - val_wine_type_loss: 0.3847 - val_wine_quality_root_mean_squared_error: 1.5231 - val_wine_type_accuracy: 0.8682
# Epoch 5/40
# 3155/3155 [==============================] - 0s 119us/sample - loss: 2.5544 - wine_quality_loss: 2.2166 - wine_type_loss: 0.3381 - wine_quality_root_mean_squared_error: 1.4887 - wine_type_accuracy: 0.9135 - val_loss: 2.2408 - val_wine_quality_loss: 1.9788 - val_wine_type_loss: 0.3033 - val_wine_quality_root_mean_squared_error: 1.3919 - val_wine_type_accuracy: 0.9392
# Epoch 6/40
# 3155/3155 [==============================] - 0s 101us/sample - loss: 2.1580 - wine_quality_loss: 1.8924 - wine_type_loss: 0.2674 - wine_quality_root_mean_squared_error: 1.3752 - wine_type_accuracy: 0.9607 - val_loss: 1.9411 - val_wine_quality_loss: 1.7264 - val_wine_type_loss: 0.2412 - val_wine_quality_root_mean_squared_error: 1.3037 - val_wine_type_accuracy: 0.9658
# Epoch 7/40
# 3155/3155 [==============================] - 0s 99us/sample - loss: 1.8883 - wine_quality_loss: 1.6747 - wine_type_loss: 0.2126 - wine_quality_root_mean_squared_error: 1.2944 - wine_type_accuracy: 0.9743 - val_loss: 1.7434 - val_wine_quality_loss: 1.5658 - val_wine_type_loss: 0.1927 - val_wine_quality_root_mean_squared_error: 1.2452 - val_wine_type_accuracy: 0.9810
# Epoch 8/40
# 3155/3155 [==============================] - 0s 117us/sample - loss: 1.6891 - wine_quality_loss: 1.5189 - wine_type_loss: 0.1724 - wine_quality_root_mean_squared_error: 1.2315 - wine_type_accuracy: 0.9819 - val_loss: 1.5600 - val_wine_quality_loss: 1.4155 - val_wine_type_loss: 0.1556 - val_wine_quality_root_mean_squared_error: 1.1850 - val_wine_type_accuracy: 0.9861
# Epoch 9/40
# 3155/3155 [==============================] - 0s 98us/sample - loss: 1.5322 - wine_quality_loss: 1.3919 - wine_type_loss: 0.1412 - wine_quality_root_mean_squared_error: 1.1794 - wine_type_accuracy: 0.9854 - val_loss: 1.4314 - val_wine_quality_loss: 1.3090 - val_wine_type_loss: 0.1287 - val_wine_quality_root_mean_squared_error: 1.1413 - val_wine_type_accuracy: 0.9861
# Epoch 10/40
# 3155/3155 [==============================] - 0s 98us/sample - loss: 1.4081 - wine_quality_loss: 1.2881 - wine_type_loss: 0.1190 - wine_quality_root_mean_squared_error: 1.1353 - wine_type_accuracy: 0.9861 - val_loss: 1.3204 - val_wine_quality_loss: 1.2148 - val_wine_type_loss: 0.1094 - val_wine_quality_root_mean_squared_error: 1.1004 - val_wine_type_accuracy: 0.9861
# Epoch 11/40
# 3155/3155 [==============================] - 0s 99us/sample - loss: 1.3025 - wine_quality_loss: 1.1981 - wine_type_loss: 0.1023 - wine_quality_root_mean_squared_error: 1.0954 - wine_type_accuracy: 0.9864 - val_loss: 1.2192 - val_wine_quality_loss: 1.1284 - val_wine_type_loss: 0.0935 - val_wine_quality_root_mean_squared_error: 1.0609 - val_wine_type_accuracy: 0.9873
# Epoch 12/40
# 3155/3155 [==============================] - 0s 117us/sample - loss: 1.2099 - wine_quality_loss: 1.1181 - wine_type_loss: 0.0898 - wine_quality_root_mean_squared_error: 1.0582 - wine_type_accuracy: 0.9867 - val_loss: 1.1365 - val_wine_quality_loss: 1.0556 - val_wine_type_loss: 0.0829 - val_wine_quality_root_mean_squared_error: 1.0264 - val_wine_type_accuracy: 0.9886
# Epoch 13/40
# 3155/3155 [==============================] - 0s 102us/sample - loss: 1.1282 - wine_quality_loss: 1.0470 - wine_type_loss: 0.0803 - wine_quality_root_mean_squared_error: 1.0237 - wine_type_accuracy: 0.9883 - val_loss: 1.0578 - val_wine_quality_loss: 0.9851 - val_wine_type_loss: 0.0742 - val_wine_quality_root_mean_squared_error: 0.9917 - val_wine_type_accuracy: 0.9886
# Epoch 14/40
# 3155/3155 [==============================] - 0s 99us/sample - loss: 1.0529 - wine_quality_loss: 0.9795 - wine_type_loss: 0.0728 - wine_quality_root_mean_squared_error: 0.9900 - wine_type_accuracy: 0.9880 - val_loss: 0.9891 - val_wine_quality_loss: 0.9226 - val_wine_type_loss: 0.0673 - val_wine_quality_root_mean_squared_error: 0.9600 - val_wine_type_accuracy: 0.9886
# Epoch 15/40
# 3155/3155 [==============================] - 0s 122us/sample - loss: 0.9855 - wine_quality_loss: 0.9177 - wine_type_loss: 0.0668 - wine_quality_root_mean_squared_error: 0.9584 - wine_type_accuracy: 0.9892 - val_loss: 0.9429 - val_wine_quality_loss: 0.8807 - val_wine_type_loss: 0.0618 - val_wine_quality_root_mean_squared_error: 0.9385 - val_wine_type_accuracy: 0.9886
# Epoch 16/40
# 3155/3155 [==============================] - 0s 98us/sample - loss: 0.9227 - wine_quality_loss: 0.8611 - wine_type_loss: 0.0622 - wine_quality_root_mean_squared_error: 0.9276 - wine_type_accuracy: 0.9895 - val_loss: 0.8964 - val_wine_quality_loss: 0.8384 - val_wine_type_loss: 0.0572 - val_wine_quality_root_mean_squared_error: 0.9159 - val_wine_type_accuracy: 0.9899
# Epoch 17/40
# 3155/3155 [==============================] - 0s 118us/sample - loss: 0.8732 - wine_quality_loss: 0.8155 - wine_type_loss: 0.0579 - wine_quality_root_mean_squared_error: 0.9029 - wine_type_accuracy: 0.9892 - val_loss: 0.8313 - val_wine_quality_loss: 0.7766 - val_wine_type_loss: 0.0541 - val_wine_quality_root_mean_squared_error: 0.8815 - val_wine_type_accuracy: 0.9899
# Epoch 18/40
# 3155/3155 [==============================] - 0s 100us/sample - loss: 0.8245 - wine_quality_loss: 0.7707 - wine_type_loss: 0.0549 - wine_quality_root_mean_squared_error: 0.8772 - wine_type_accuracy: 0.9899 - val_loss: 0.7871 - val_wine_quality_loss: 0.7352 - val_wine_type_loss: 0.0512 - val_wine_quality_root_mean_squared_error: 0.8576 - val_wine_type_accuracy: 0.9886
# Epoch 19/40
# 3155/3155 [==============================] - 0s 96us/sample - loss: 0.7801 - wine_quality_loss: 0.7289 - wine_type_loss: 0.0522 - wine_quality_root_mean_squared_error: 0.8532 - wine_type_accuracy: 0.9902 - val_loss: 0.7425 - val_wine_quality_loss: 0.6926 - val_wine_type_loss: 0.0488 - val_wine_quality_root_mean_squared_error: 0.8327 - val_wine_type_accuracy: 0.9886
# Epoch 20/40
# 3155/3155 [==============================] - 0s 117us/sample - loss: 0.7390 - wine_quality_loss: 0.6957 - wine_type_loss: 0.0498 - wine_quality_root_mean_squared_error: 0.8301 - wine_type_accuracy: 0.9902 - val_loss: 0.7050 - val_wine_quality_loss: 0.6571 - val_wine_type_loss: 0.0468 - val_wine_quality_root_mean_squared_error: 0.8111 - val_wine_type_accuracy: 0.9886
# Epoch 21/40
# 3155/3155 [==============================] - 0s 96us/sample - loss: 0.7033 - wine_quality_loss: 0.6551 - wine_type_loss: 0.0479 - wine_quality_root_mean_squared_error: 0.8096 - wine_type_accuracy: 0.9902 - val_loss: 0.6737 - val_wine_quality_loss: 0.6272 - val_wine_type_loss: 0.0451 - val_wine_quality_root_mean_squared_error: 0.7927 - val_wine_type_accuracy: 0.9899
# Epoch 22/40
# 3155/3155 [==============================] - 0s 100us/sample - loss: 0.6693 - wine_quality_loss: 0.6230 - wine_type_loss: 0.0463 - wine_quality_root_mean_squared_error: 0.7893 - wine_type_accuracy: 0.9902 - val_loss: 0.6380 - val_wine_quality_loss: 0.5928 - val_wine_type_loss: 0.0439 - val_wine_quality_root_mean_squared_error: 0.7706 - val_wine_type_accuracy: 0.9911
# Epoch 23/40
# 3155/3155 [==============================] - 0s 100us/sample - loss: 0.6396 - wine_quality_loss: 0.5963 - wine_type_loss: 0.0447 - wine_quality_root_mean_squared_error: 0.7712 - wine_type_accuracy: 0.9902 - val_loss: 0.6085 - val_wine_quality_loss: 0.5645 - val_wine_type_loss: 0.0425 - val_wine_quality_root_mean_squared_error: 0.7521 - val_wine_type_accuracy: 0.9911
# Epoch 24/40
# 3155/3155 [==============================] - 0s 114us/sample - loss: 0.6085 - wine_quality_loss: 0.5660 - wine_type_loss: 0.0435 - wine_quality_root_mean_squared_error: 0.7517 - wine_type_accuracy: 0.9908 - val_loss: 0.5771 - val_wine_quality_loss: 0.5347 - val_wine_type_loss: 0.0415 - val_wine_quality_root_mean_squared_error: 0.7316 - val_wine_type_accuracy: 0.9911
# Epoch 25/40
# 3155/3155 [==============================] - 0s 126us/sample - loss: 0.5828 - wine_quality_loss: 0.5396 - wine_type_loss: 0.0422 - wine_quality_root_mean_squared_error: 0.7352 - wine_type_accuracy: 0.9911 - val_loss: 0.5550 - val_wine_quality_loss: 0.5133 - val_wine_type_loss: 0.0405 - val_wine_quality_root_mean_squared_error: 0.7171 - val_wine_type_accuracy: 0.9924
# Epoch 26/40
# 3155/3155 [==============================] - 0s 100us/sample - loss: 0.5585 - wine_quality_loss: 0.5181 - wine_type_loss: 0.0412 - wine_quality_root_mean_squared_error: 0.7192 - wine_type_accuracy: 0.9908 - val_loss: 0.5332 - val_wine_quality_loss: 0.4922 - val_wine_type_loss: 0.0396 - val_wine_quality_root_mean_squared_error: 0.7023 - val_wine_type_accuracy: 0.9924
# Epoch 27/40
# 3155/3155 [==============================] - 0s 100us/sample - loss: 0.5366 - wine_quality_loss: 0.4970 - wine_type_loss: 0.0403 - wine_quality_root_mean_squared_error: 0.7045 - wine_type_accuracy: 0.9911 - val_loss: 0.5154 - val_wine_quality_loss: 0.4750 - val_wine_type_loss: 0.0387 - val_wine_quality_root_mean_squared_error: 0.6901 - val_wine_type_accuracy: 0.9924
# Epoch 28/40
# 3155/3155 [==============================] - 0s 117us/sample - loss: 0.5173 - wine_quality_loss: 0.4773 - wine_type_loss: 0.0395 - wine_quality_root_mean_squared_error: 0.6912 - wine_type_accuracy: 0.9908 - val_loss: 0.4924 - val_wine_quality_loss: 0.4528 - val_wine_type_loss: 0.0383 - val_wine_quality_root_mean_squared_error: 0.6736 - val_wine_type_accuracy: 0.9924
# Epoch 29/40
# 3155/3155 [==============================] - 0s 98us/sample - loss: 0.4985 - wine_quality_loss: 0.4595 - wine_type_loss: 0.0385 - wine_quality_root_mean_squared_error: 0.6781 - wine_type_accuracy: 0.9914 - val_loss: 0.4929 - val_wine_quality_loss: 0.4546 - val_wine_type_loss: 0.0376 - val_wine_quality_root_mean_squared_error: 0.6745 - val_wine_type_accuracy: 0.9924
# Epoch 30/40
# 3155/3155 [==============================] - 0s 105us/sample - loss: 0.4829 - wine_quality_loss: 0.4442 - wine_type_loss: 0.0379 - wine_quality_root_mean_squared_error: 0.6670 - wine_type_accuracy: 0.9911 - val_loss: 0.4667 - val_wine_quality_loss: 0.4280 - val_wine_type_loss: 0.0371 - val_wine_quality_root_mean_squared_error: 0.6551 - val_wine_type_accuracy: 0.9924
# Epoch 31/40
# 3155/3155 [==============================] - 0s 114us/sample - loss: 0.4673 - wine_quality_loss: 0.4303 - wine_type_loss: 0.0373 - wine_quality_root_mean_squared_error: 0.6558 - wine_type_accuracy: 0.9921 - val_loss: 0.4503 - val_wine_quality_loss: 0.4125 - val_wine_type_loss: 0.0367 - val_wine_quality_root_mean_squared_error: 0.6428 - val_wine_type_accuracy: 0.9924
# Epoch 32/40
# 3155/3155 [==============================] - 0s 100us/sample - loss: 0.4550 - wine_quality_loss: 0.4186 - wine_type_loss: 0.0367 - wine_quality_root_mean_squared_error: 0.6468 - wine_type_accuracy: 0.9918 - val_loss: 0.4365 - val_wine_quality_loss: 0.3989 - val_wine_type_loss: 0.0363 - val_wine_quality_root_mean_squared_error: 0.6323 - val_wine_type_accuracy: 0.9924
# Epoch 33/40
# 3155/3155 [==============================] - 0s 99us/sample - loss: 0.4447 - wine_quality_loss: 0.4084 - wine_type_loss: 0.0360 - wine_quality_root_mean_squared_error: 0.6392 - wine_type_accuracy: 0.9933 - val_loss: 0.4290 - val_wine_quality_loss: 0.3920 - val_wine_type_loss: 0.0359 - val_wine_quality_root_mean_squared_error: 0.6267 - val_wine_type_accuracy: 0.9924
# Epoch 34/40
# 3155/3155 [==============================] - 0s 96us/sample - loss: 0.4339 - wine_quality_loss: 0.3990 - wine_type_loss: 0.0354 - wine_quality_root_mean_squared_error: 0.6312 - wine_type_accuracy: 0.9933 - val_loss: 0.4235 - val_wine_quality_loss: 0.3864 - val_wine_type_loss: 0.0356 - val_wine_quality_root_mean_squared_error: 0.6225 - val_wine_type_accuracy: 0.9924
# Epoch 35/40
# 3155/3155 [==============================] - 0s 120us/sample - loss: 0.4229 - wine_quality_loss: 0.3876 - wine_type_loss: 0.0350 - wine_quality_root_mean_squared_error: 0.6227 - wine_type_accuracy: 0.9927 - val_loss: 0.4124 - val_wine_quality_loss: 0.3763 - val_wine_type_loss: 0.0351 - val_wine_quality_root_mean_squared_error: 0.6139 - val_wine_type_accuracy: 0.9924
# Epoch 36/40
# 3155/3155 [==============================] - 0s 104us/sample - loss: 0.4164 - wine_quality_loss: 0.3823 - wine_type_loss: 0.0344 - wine_quality_root_mean_squared_error: 0.6179 - wine_type_accuracy: 0.9940 - val_loss: 0.4044 - val_wine_quality_loss: 0.3680 - val_wine_type_loss: 0.0348 - val_wine_quality_root_mean_squared_error: 0.6077 - val_wine_type_accuracy: 0.9924
# Epoch 37/40
# 3155/3155 [==============================] - 0s 115us/sample - loss: 0.4067 - wine_quality_loss: 0.3720 - wine_type_loss: 0.0340 - wine_quality_root_mean_squared_error: 0.6104 - wine_type_accuracy: 0.9943 - val_loss: 0.4070 - val_wine_quality_loss: 0.3713 - val_wine_type_loss: 0.0345 - val_wine_quality_root_mean_squared_error: 0.6101 - val_wine_type_accuracy: 0.9924
# Epoch 38/40
# 3155/3155 [==============================] - 0s 101us/sample - loss: 0.4013 - wine_quality_loss: 0.3673 - wine_type_loss: 0.0336 - wine_quality_root_mean_squared_error: 0.6064 - wine_type_accuracy: 0.9943 - val_loss: 0.3952 - val_wine_quality_loss: 0.3593 - val_wine_type_loss: 0.0344 - val_wine_quality_root_mean_squared_error: 0.6004 - val_wine_type_accuracy: 0.9924
# Epoch 39/40
# 3155/3155 [==============================] - 0s 114us/sample - loss: 0.3958 - wine_quality_loss: 0.3632 - wine_type_loss: 0.0331 - wine_quality_root_mean_squared_error: 0.6022 - wine_type_accuracy: 0.9943 - val_loss: 0.3843 - val_wine_quality_loss: 0.3490 - val_wine_type_loss: 0.0338 - val_wine_quality_root_mean_squared_error: 0.5917 - val_wine_type_accuracy: 0.9937
# Epoch 40/40
# 3155/3155 [==============================] - 0s 108us/sample - loss: 0.3902 - wine_quality_loss: 0.3565 - wine_type_loss: 0.0327 - wine_quality_root_mean_squared_error: 0.5978 - wine_type_accuracy: 0.9946 - val_loss: 0.3889 - val_wine_quality_loss: 0.3544 - val_wine_type_loss: 0.0337 - val_wine_quality_root_mean_squared_error: 0.5957 - val_wine_type_accuracy: 0.9937

# %%
# Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
# You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



history = model.fit(norm_train_X, train_Y,
                    epochs = 40, validation_data=(norm_val_X, val_Y))
# Out:
# Train on 3155 samples, validate on 789 samples
# Epoch 1/40
# 3155/3155 [==============================] - 0s 76us/sample - loss: 0.3830 - wine_quality_loss: 0.3529 - wine_type_loss: 0.0308 - wine_quality_root_mean_squared_error: 0.5934 - wine_type_accuracy: 0.9940 - val_loss: 0.3818 - val_wine_quality_loss: 0.3512 - val_wine_type_loss: 0.0291 - val_wine_quality_root_mean_squared_error: 0.5936 - val_wine_type_accuracy: 0.9949
# Epoch 2/40
# 3155/3155 [==============================] - 0s 89us/sample - loss: 0.3792 - wine_quality_loss: 0.3489 - wine_type_loss: 0.0304 - wine_quality_root_mean_squared_error: 0.5905 - wine_type_accuracy: 0.9943 - val_loss: 0.3730 - val_wine_quality_loss: 0.3424 - val_wine_type_loss: 0.0293 - val_wine_quality_root_mean_squared_error: 0.5859 - val_wine_type_accuracy: 0.9949
# Epoch 3/40
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3748 - wine_quality_loss: 0.3448 - wine_type_loss: 0.0303 - wine_quality_root_mean_squared_error: 0.5869 - wine_type_accuracy: 0.9943 - val_loss: 0.3712 - val_wine_quality_loss: 0.3405 - val_wine_type_loss: 0.0290 - val_wine_quality_root_mean_squared_error: 0.5847 - val_wine_type_accuracy: 0.9949
# Epoch 4/40
# 3155/3155 [==============================] - 0s 74us/sample - loss: 0.3713 - wine_quality_loss: 0.3412 - wine_type_loss: 0.0301 - wine_quality_root_mean_squared_error: 0.5842 - wine_type_accuracy: 0.9940 - val_loss: 0.3716 - val_wine_quality_loss: 0.3410 - val_wine_type_loss: 0.0289 - val_wine_quality_root_mean_squared_error: 0.5851 - val_wine_type_accuracy: 0.9949
# Epoch 5/40
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3687 - wine_quality_loss: 0.3397 - wine_type_loss: 0.0298 - wine_quality_root_mean_squared_error: 0.5822 - wine_type_accuracy: 0.9940 - val_loss: 0.3626 - val_wine_quality_loss: 0.3326 - val_wine_type_loss: 0.0286 - val_wine_quality_root_mean_squared_error: 0.5776 - val_wine_type_accuracy: 0.9949
# Epoch 6/40
# 3155/3155 [==============================] - 0s 88us/sample - loss: 0.3641 - wine_quality_loss: 0.3343 - wine_type_loss: 0.0294 - wine_quality_root_mean_squared_error: 0.5784 - wine_type_accuracy: 0.9943 - val_loss: 0.3621 - val_wine_quality_loss: 0.3323 - val_wine_type_loss: 0.0285 - val_wine_quality_root_mean_squared_error: 0.5773 - val_wine_type_accuracy: 0.9949
# Epoch 7/40
# 3155/3155 [==============================] - 0s 74us/sample - loss: 0.3612 - wine_quality_loss: 0.3321 - wine_type_loss: 0.0292 - wine_quality_root_mean_squared_error: 0.5761 - wine_type_accuracy: 0.9943 - val_loss: 0.3573 - val_wine_quality_loss: 0.3278 - val_wine_type_loss: 0.0282 - val_wine_quality_root_mean_squared_error: 0.5733 - val_wine_type_accuracy: 0.9949
# Epoch 8/40
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.3598 - wine_quality_loss: 0.3310 - wine_type_loss: 0.0289 - wine_quality_root_mean_squared_error: 0.5752 - wine_type_accuracy: 0.9946 - val_loss: 0.3594 - val_wine_quality_loss: 0.3299 - val_wine_type_loss: 0.0280 - val_wine_quality_root_mean_squared_error: 0.5754 - val_wine_type_accuracy: 0.9949
# Epoch 9/40
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.3580 - wine_quality_loss: 0.3302 - wine_type_loss: 0.0286 - wine_quality_root_mean_squared_error: 0.5739 - wine_type_accuracy: 0.9943 - val_loss: 0.3566 - val_wine_quality_loss: 0.3270 - val_wine_type_loss: 0.0281 - val_wine_quality_root_mean_squared_error: 0.5729 - val_wine_type_accuracy: 0.9949
# Epoch 10/40
# 3155/3155 [==============================] - 0s 88us/sample - loss: 0.3543 - wine_quality_loss: 0.3261 - wine_type_loss: 0.0285 - wine_quality_root_mean_squared_error: 0.5707 - wine_type_accuracy: 0.9946 - val_loss: 0.3532 - val_wine_quality_loss: 0.3239 - val_wine_type_loss: 0.0279 - val_wine_quality_root_mean_squared_error: 0.5701 - val_wine_type_accuracy: 0.9949
# Epoch 11/40
# 3155/3155 [==============================] - 0s 75us/sample - loss: 0.3529 - wine_quality_loss: 0.3244 - wine_type_loss: 0.0286 - wine_quality_root_mean_squared_error: 0.5697 - wine_type_accuracy: 0.9946 - val_loss: 0.3566 - val_wine_quality_loss: 0.3273 - val_wine_type_loss: 0.0278 - val_wine_quality_root_mean_squared_error: 0.5731 - val_wine_type_accuracy: 0.9949
# Epoch 12/40
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.3512 - wine_quality_loss: 0.3228 - wine_type_loss: 0.0281 - wine_quality_root_mean_squared_error: 0.5684 - wine_type_accuracy: 0.9946 - val_loss: 0.3528 - val_wine_quality_loss: 0.3235 - val_wine_type_loss: 0.0279 - val_wine_quality_root_mean_squared_error: 0.5697 - val_wine_type_accuracy: 0.9949
# Epoch 13/40
# 3155/3155 [==============================] - 0s 88us/sample - loss: 0.3488 - wine_quality_loss: 0.3210 - wine_type_loss: 0.0279 - wine_quality_root_mean_squared_error: 0.5664 - wine_type_accuracy: 0.9943 - val_loss: 0.3577 - val_wine_quality_loss: 0.3285 - val_wine_type_loss: 0.0278 - val_wine_quality_root_mean_squared_error: 0.5740 - val_wine_type_accuracy: 0.9949
# Epoch 14/40
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.3480 - wine_quality_loss: 0.3198 - wine_type_loss: 0.0276 - wine_quality_root_mean_squared_error: 0.5660 - wine_type_accuracy: 0.9946 - val_loss: 0.3505 - val_wine_quality_loss: 0.3214 - val_wine_type_loss: 0.0278 - val_wine_quality_root_mean_squared_error: 0.5677 - val_wine_type_accuracy: 0.9949
# Epoch 15/40
# 3155/3155 [==============================] - 0s 76us/sample - loss: 0.3453 - wine_quality_loss: 0.3173 - wine_type_loss: 0.0274 - wine_quality_root_mean_squared_error: 0.5637 - wine_type_accuracy: 0.9946 - val_loss: 0.3472 - val_wine_quality_loss: 0.3184 - val_wine_type_loss: 0.0276 - val_wine_quality_root_mean_squared_error: 0.5650 - val_wine_type_accuracy: 0.9949
# Epoch 16/40
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.3442 - wine_quality_loss: 0.3168 - wine_type_loss: 0.0272 - wine_quality_root_mean_squared_error: 0.5629 - wine_type_accuracy: 0.9952 - val_loss: 0.3457 - val_wine_quality_loss: 0.3172 - val_wine_type_loss: 0.0275 - val_wine_quality_root_mean_squared_error: 0.5638 - val_wine_type_accuracy: 0.9949
# Epoch 17/40
# 3155/3155 [==============================] - 0s 91us/sample - loss: 0.3422 - wine_quality_loss: 0.3149 - wine_type_loss: 0.0270 - wine_quality_root_mean_squared_error: 0.5613 - wine_type_accuracy: 0.9952 - val_loss: 0.3448 - val_wine_quality_loss: 0.3164 - val_wine_type_loss: 0.0273 - val_wine_quality_root_mean_squared_error: 0.5632 - val_wine_type_accuracy: 0.9949
# Epoch 18/40
# 3155/3155 [==============================] - 0s 74us/sample - loss: 0.3416 - wine_quality_loss: 0.3141 - wine_type_loss: 0.0268 - wine_quality_root_mean_squared_error: 0.5610 - wine_type_accuracy: 0.9949 - val_loss: 0.3492 - val_wine_quality_loss: 0.3207 - val_wine_type_loss: 0.0272 - val_wine_quality_root_mean_squared_error: 0.5671 - val_wine_type_accuracy: 0.9949
# Epoch 19/40
# 3155/3155 [==============================] - 0s 76us/sample - loss: 0.3408 - wine_quality_loss: 0.3134 - wine_type_loss: 0.0283 - wine_quality_root_mean_squared_error: 0.5603 - wine_type_accuracy: 0.9952 - val_loss: 0.3442 - val_wine_quality_loss: 0.3156 - val_wine_type_loss: 0.0272 - val_wine_quality_root_mean_squared_error: 0.5627 - val_wine_type_accuracy: 0.9949
# Epoch 20/40
# 3155/3155 [==============================] - 0s 89us/sample - loss: 0.3386 - wine_quality_loss: 0.3114 - wine_type_loss: 0.0265 - wine_quality_root_mean_squared_error: 0.5586 - wine_type_accuracy: 0.9949 - val_loss: 0.3546 - val_wine_quality_loss: 0.3262 - val_wine_type_loss: 0.0271 - val_wine_quality_root_mean_squared_error: 0.5720 - val_wine_type_accuracy: 0.9949
# Epoch 21/40
# 3155/3155 [==============================] - 0s 88us/sample - loss: 0.3376 - wine_quality_loss: 0.3111 - wine_type_loss: 0.0263 - wine_quality_root_mean_squared_error: 0.5579 - wine_type_accuracy: 0.9952 - val_loss: 0.3442 - val_wine_quality_loss: 0.3159 - val_wine_type_loss: 0.0270 - val_wine_quality_root_mean_squared_error: 0.5629 - val_wine_type_accuracy: 0.9949
# Epoch 22/40
# 3155/3155 [==============================] - 0s 77us/sample - loss: 0.3357 - wine_quality_loss: 0.3100 - wine_type_loss: 0.0262 - wine_quality_root_mean_squared_error: 0.5563 - wine_type_accuracy: 0.9952 - val_loss: 0.3523 - val_wine_quality_loss: 0.3238 - val_wine_type_loss: 0.0271 - val_wine_quality_root_mean_squared_error: 0.5700 - val_wine_type_accuracy: 0.9949
# Epoch 23/40
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.3348 - wine_quality_loss: 0.3081 - wine_type_loss: 0.0260 - wine_quality_root_mean_squared_error: 0.5555 - wine_type_accuracy: 0.9952 - val_loss: 0.3431 - val_wine_quality_loss: 0.3149 - val_wine_type_loss: 0.0270 - val_wine_quality_root_mean_squared_error: 0.5619 - val_wine_type_accuracy: 0.9949
# Epoch 24/40
# 3155/3155 [==============================] - 0s 93us/sample - loss: 0.3324 - wine_quality_loss: 0.3066 - wine_type_loss: 0.0259 - wine_quality_root_mean_squared_error: 0.5536 - wine_type_accuracy: 0.9952 - val_loss: 0.3449 - val_wine_quality_loss: 0.3170 - val_wine_type_loss: 0.0270 - val_wine_quality_root_mean_squared_error: 0.5635 - val_wine_type_accuracy: 0.9949
# Epoch 25/40
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.3314 - wine_quality_loss: 0.3050 - wine_type_loss: 0.0256 - wine_quality_root_mean_squared_error: 0.5529 - wine_type_accuracy: 0.9952 - val_loss: 0.3576 - val_wine_quality_loss: 0.3297 - val_wine_type_loss: 0.0269 - val_wine_quality_root_mean_squared_error: 0.5748 - val_wine_type_accuracy: 0.9949
# Epoch 26/40
# 3155/3155 [==============================] - 0s 75us/sample - loss: 0.3312 - wine_quality_loss: 0.3067 - wine_type_loss: 0.0255 - wine_quality_root_mean_squared_error: 0.5528 - wine_type_accuracy: 0.9952 - val_loss: 0.3458 - val_wine_quality_loss: 0.3179 - val_wine_type_loss: 0.0269 - val_wine_quality_root_mean_squared_error: 0.5645 - val_wine_type_accuracy: 0.9949
# Epoch 27/40
# 3155/3155 [==============================] - 0s 89us/sample - loss: 0.3312 - wine_quality_loss: 0.3056 - wine_type_loss: 0.0254 - wine_quality_root_mean_squared_error: 0.5529 - wine_type_accuracy: 0.9952 - val_loss: 0.3423 - val_wine_quality_loss: 0.3143 - val_wine_type_loss: 0.0267 - val_wine_quality_root_mean_squared_error: 0.5615 - val_wine_type_accuracy: 0.9949
# Epoch 28/40
# 3155/3155 [==============================] - 0s 92us/sample - loss: 0.3288 - wine_quality_loss: 0.3038 - wine_type_loss: 0.0252 - wine_quality_root_mean_squared_error: 0.5509 - wine_type_accuracy: 0.9952 - val_loss: 0.3394 - val_wine_quality_loss: 0.3118 - val_wine_type_loss: 0.0266 - val_wine_quality_root_mean_squared_error: 0.5590 - val_wine_type_accuracy: 0.9949
# Epoch 29/40
# 3155/3155 [==============================] - 0s 72us/sample - loss: 0.3284 - wine_quality_loss: 0.3039 - wine_type_loss: 0.0251 - wine_quality_root_mean_squared_error: 0.5507 - wine_type_accuracy: 0.9952 - val_loss: 0.3387 - val_wine_quality_loss: 0.3110 - val_wine_type_loss: 0.0267 - val_wine_quality_root_mean_squared_error: 0.5583 - val_wine_type_accuracy: 0.9949
# Epoch 30/40
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.3274 - wine_quality_loss: 0.3031 - wine_type_loss: 0.0249 - wine_quality_root_mean_squared_error: 0.5499 - wine_type_accuracy: 0.9952 - val_loss: 0.3417 - val_wine_quality_loss: 0.3139 - val_wine_type_loss: 0.0267 - val_wine_quality_root_mean_squared_error: 0.5610 - val_wine_type_accuracy: 0.9949
# Epoch 31/40
# 3155/3155 [==============================] - 0s 89us/sample - loss: 0.3267 - wine_quality_loss: 0.3021 - wine_type_loss: 0.0248 - wine_quality_root_mean_squared_error: 0.5494 - wine_type_accuracy: 0.9952 - val_loss: 0.3438 - val_wine_quality_loss: 0.3160 - val_wine_type_loss: 0.0265 - val_wine_quality_root_mean_squared_error: 0.5630 - val_wine_type_accuracy: 0.9949
# Epoch 32/40
# 3155/3155 [==============================] - 0s 75us/sample - loss: 0.3255 - wine_quality_loss: 0.3010 - wine_type_loss: 0.0246 - wine_quality_root_mean_squared_error: 0.5485 - wine_type_accuracy: 0.9952 - val_loss: 0.3544 - val_wine_quality_loss: 0.3268 - val_wine_type_loss: 0.0264 - val_wine_quality_root_mean_squared_error: 0.5725 - val_wine_type_accuracy: 0.9949
# Epoch 33/40
# 3155/3155 [==============================] - 0s 88us/sample - loss: 0.3241 - wine_quality_loss: 0.2994 - wine_type_loss: 0.0244 - wine_quality_root_mean_squared_error: 0.5474 - wine_type_accuracy: 0.9952 - val_loss: 0.3394 - val_wine_quality_loss: 0.3119 - val_wine_type_loss: 0.0262 - val_wine_quality_root_mean_squared_error: 0.5593 - val_wine_type_accuracy: 0.9949
# Epoch 34/40
# 3155/3155 [==============================] - 0s 89us/sample - loss: 0.3239 - wine_quality_loss: 0.2998 - wine_type_loss: 0.0246 - wine_quality_root_mean_squared_error: 0.5473 - wine_type_accuracy: 0.9952 - val_loss: 0.3371 - val_wine_quality_loss: 0.3099 - val_wine_type_loss: 0.0263 - val_wine_quality_root_mean_squared_error: 0.5572 - val_wine_type_accuracy: 0.9949
# Epoch 35/40
# 3155/3155 [==============================] - 0s 76us/sample - loss: 0.3226 - wine_quality_loss: 0.2985 - wine_type_loss: 0.0242 - wine_quality_root_mean_squared_error: 0.5462 - wine_type_accuracy: 0.9956 - val_loss: 0.3472 - val_wine_quality_loss: 0.3198 - val_wine_type_loss: 0.0262 - val_wine_quality_root_mean_squared_error: 0.5663 - val_wine_type_accuracy: 0.9949
# Epoch 36/40
# 3155/3155 [==============================] - 0s 76us/sample - loss: 0.3223 - wine_quality_loss: 0.2984 - wine_type_loss: 0.0243 - wine_quality_root_mean_squared_error: 0.5461 - wine_type_accuracy: 0.9956 - val_loss: 0.3377 - val_wine_quality_loss: 0.3105 - val_wine_type_loss: 0.0261 - val_wine_quality_root_mean_squared_error: 0.5579 - val_wine_type_accuracy: 0.9949
# Epoch 37/40
# 3155/3155 [==============================] - 0s 90us/sample - loss: 0.3215 - wine_quality_loss: 0.2974 - wine_type_loss: 0.0238 - wine_quality_root_mean_squared_error: 0.5455 - wine_type_accuracy: 0.9956 - val_loss: 0.3391 - val_wine_quality_loss: 0.3118 - val_wine_type_loss: 0.0261 - val_wine_quality_root_mean_squared_error: 0.5591 - val_wine_type_accuracy: 0.9949
# Epoch 38/40
# 3155/3155 [==============================] - 0s 87us/sample - loss: 0.3210 - wine_quality_loss: 0.2973 - wine_type_loss: 0.0237 - wine_quality_root_mean_squared_error: 0.5452 - wine_type_accuracy: 0.9956 - val_loss: 0.3385 - val_wine_quality_loss: 0.3112 - val_wine_type_loss: 0.0261 - val_wine_quality_root_mean_squared_error: 0.5586 - val_wine_type_accuracy: 0.9949
# Epoch 39/40
# 3155/3155 [==============================] - 0s 75us/sample - loss: 0.3194 - wine_quality_loss: 0.2964 - wine_type_loss: 0.0235 - wine_quality_root_mean_squared_error: 0.5439 - wine_type_accuracy: 0.9956 - val_loss: 0.3468 - val_wine_quality_loss: 0.3194 - val_wine_type_loss: 0.0261 - val_wine_quality_root_mean_squared_error: 0.5660 - val_wine_type_accuracy: 0.9949
# Epoch 40/40
# 3155/3155 [==============================] - 0s 87us/sample - loss: 0.3186 - wine_quality_loss: 0.2956 - wine_type_loss: 0.0234 - wine_quality_root_mean_squared_error: 0.5432 - wine_type_accuracy: 0.9956 - val_loss: 0.3360 - val_wine_quality_loss: 0.3088 - val_wine_type_loss: 0.0259 - val_wine_quality_root_mean_squared_error: 0.5565 - val_wine_type_accuracy: 0.9949

# %%
utils.test_history(history)
# Out:
#  All public tests passed

# %%
# Gather the training metrics
loss, wine_quality_loss, wine_type_loss, wine_quality_rmse, wine_type_accuracy = model.evaluate(x=norm_val_X, y=val_Y)

print()
print(f'loss: {loss}')
print(f'wine_quality_loss: {wine_quality_loss}')
print(f'wine_type_loss: {wine_type_loss}')
print(f'wine_quality_rmse: {wine_quality_rmse}')
print(f'wine_type_accuracy: {wine_type_accuracy}')

# EXPECTED VALUES
# ~ 0.30 - 0.38
# ~ 0.30 - 0.38
# ~ 0.018 - 0.036
# ~ 0.50 - 0.62
# ~ 0.97 - 1.0

# Example:
#0.3657050132751465
#0.3463745415210724
#0.019330406561493874
#0.5885359048843384
#0.9974651336669922
# Out:
# 789/789 [==============================] - 0s 27us/sample - loss: 0.3889 - wine_quality_loss: 0.3544 - wine_type_loss: 0.0337 - wine_quality_root_mean_squared_error: 0.5957 - wine_type_accuracy: 0.9937
#
# loss: 0.3888693870775902
# wine_quality_loss: 0.35439085960388184
# wine_type_loss: 0.033650562167167664
# wine_quality_rmse: 0.595695972442627
# wine_type_accuracy: 0.9936628937721252

# %% [markdown]
# ## Analyze the Model Performance
#
# Note that the model has two outputs. The output at index 0 is quality and index 1 is wine type
#
# So, round the quality predictions to the nearest integer.

# %%
predictions = model.predict(norm_test_X)
quality_pred = predictions[0]
type_pred = predictions[1]

# %%
print(quality_pred[0])

# EXPECTED OUTPUT
# 5.4 - 6.0
# Out:
# [5.287132]

# %%
print(type_pred[0])
print(type_pred[944])

# EXPECTED OUTPUT
# A number close to zero
# A number close to or equal to 1
# Out:
# [0.00323989]
# [0.99987674]

# %% [markdown]
# ### Plot Utilities
#
# We define a few utilities to visualize the model performance.

# %%
def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0,ylim)
    plt.plot(history.history[metric_name],color='blue',label=metric_name)
    plt.plot(history.history['val_' + metric_name],color='green',label='val_' + metric_name)

# %%
def plot_confusion_matrix(y_true, y_pred, title='', labels=[0,1]):
    cm = confusion_matrix(test_Y[1], np.round(type_pred), labels=[0, 1])
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=[0, 1])
    disp.plot(values_format='d');

# %%
def plot_diff(y_true, y_pred, title = '' ):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.plot([-100, 100], [-100, 100])
    return plt

# %% [markdown]
# ### Plots for Metrics

# %%
plot_metrics('wine_quality_root_mean_squared_error', 'RMSE', ylim=2)

# %%
plot_metrics('wine_type_loss', 'Wine Type Loss', ylim=0.2)

# %% [markdown]
# ### Plots for Confusion Matrix
#
# Plot the confusion matrices for wine type. You can see that the model performs well for prediction of wine type from the confusion matrix and the loss metrics.

# %%
plot_confusion_matrix(test_Y[1], np.round(type_pred), title='Wine Type', labels = [0, 1])

# %%
scatter_plot = plot_diff(test_Y[0], quality_pred, title='Type')

# %% [markdown]
# ## Submit your work
#
# Save your work and click the `Submit` button on the upper right of this lab environment (see the image below for reference). If you don't see it, please try refreshing your browser and check again. If the issue persists, please report it on the [DLAI Forum](https://community.deeplearning.ai/?utm_campaign=forum-engagement&utm_medium=long-form-courses&utm_source=coursera).
#
# <img src='submit.png' width=200px>
